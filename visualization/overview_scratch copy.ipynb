# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "visualization" else Path.cwd()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

import pandas as pd
from ppm.wandb_utils import load_multiple_experiments

plots_dir = PROJECT_ROOT / "plots"
plots_dir.mkdir(parents=True, exist_ok=True)

# %%
PROJECTS_SCRATCH = [
    "BPI19_lrz_nanogpt_scratch_new_001",
    "BPI17_lrz_nanogpt_scratch_new_001",
    "BPI15_lrz_nanogpt_scratch_new_001",
    "BPI12_lrz_nanogpt_scratch_new_001",
]

PROJECTS_DISTILL = [
    "BPI19_lrz_distill_fixed_001",
    "BPI15_lrz_distill_fixed_001",
    "BPI17_lrz_distill_fixed_001",
    "BPI12_lrz_distill_fixed_001",
    "BPI20TPD_lrz_distill_fixed_001",
    "BPI20RFP_lrz_distill_fixed_001",
    "BPI20PTC_lrz_distill_fixed_001",
]

PROJECTS_FINETUNE = [
    "BPI12_lrz_001_003",
    "BPI19_lrz_002_002",
    "BPI17_lrz_002_002",
    "BPI15_lrz_002_001",
    "BPI17_spark_002_002",
    "BPI20_lrz_002_002",
    "BPI17_spark_002_001",
    "BPI12_spark_002_003",
    "BPI20_RFP_lrz_002",
    "BPI12_spark_002_002",
    "BPI20_PTC_lrz_002",
    "BPI19_lrz_002",
    "BPI15_lrz_002",
    "BPI12_spark_002",
    "BPI20_TPD_spark_001",
    "BPI17_lrz_002",
    "BPI20_PTC_spark_001",
    "BPI19_lrz_001",
    "BPI15_lrz_001",
    "BPI20_TPD_lrz_001",
    "BPI20_RFP_lrz_001",
    "BPI20_PTC_lrz_001",
    "lstm_bpi12_size100_layers3_001",
    "BPI17_lrz_001",
    "BPI12_lrz_001",
]

INCLUDE_BASELINE = True
PROJECTS = PROJECTS_SCRATCH + PROJECTS_DISTILL + PROJECTS_FINETUNE
if INCLUDE_BASELINE and "baseline-nep" not in PROJECTS:
    PROJECTS.append("baseline-nep")

runs_raw, _ = load_multiple_experiments(PROJECTS, force_update=False)
# Out:
# Database already exists: /app/visualization/metrics/BPI19_lrz_nanogpt_scratch_new_001.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/metrics/BPI17_lrz_nanogpt_scratch_new_001.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/metrics/BPI15_lrz_nanogpt_scratch_new_001.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/metrics/BPI12_lrz_nanogpt_scratch_new_001.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/metrics/BPI19_lrz_distill_fixed_001.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/metrics/BPI15_lrz_distill_fixed_001.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/metrics/BPI17_lrz_distill_fixed_001.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/metrics/BPI12_lrz_distill_fixed_001.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/metrics/BPI20TPD_lrz_distill_fixed_001.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/metrics/BPI20RFP_lrz_distill_fixed_001.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/metrics/BPI20PTC_lrz_distill_fixed_001.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/metrics/BPI12_lrz_001_003.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/metrics/BPI19_lrz_002_002.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/metrics/BPI17_lrz_002_002.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/metrics/BPI15_lrz_002_001.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/metrics/BPI17_spark_002_002.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/metrics/BPI20_lrz_002_002.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/metrics/BPI17_spark_002_001.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/metrics/BPI12_spark_002_003.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/metrics/BPI20_RFP_lrz_002.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/metrics/BPI12_spark_002_002.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/metrics/BPI20_PTC_lrz_002.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/metrics/BPI19_lrz_002.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/metrics/BPI15_lrz_002.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/metrics/BPI12_spark_002.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/metrics/BPI20_TPD_spark_001.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/metrics/BPI17_lrz_002.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/metrics/BPI20_PTC_spark_001.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/metrics/BPI19_lrz_001.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/metrics/BPI15_lrz_001.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/metrics/BPI20_TPD_lrz_001.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/metrics/BPI20_RFP_lrz_001.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/metrics/BPI20_PTC_lrz_001.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/metrics/lstm_bpi12_size100_layers3_001.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/metrics/BPI17_lrz_001.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/metrics/BPI12_lrz_001.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/metrics/baseline-nep.db
# Use force_update=True to re-fetch from wandb
# Loaded 1231 runs from 37 experiments
# Datasets: ['BPI19', 'BPI17', 'BPI15', 'BPI12', 'BPI20TravelPermitData', 'BPI20RequestForPayment', 'BPI20PrepaidTravelCosts']

# %%
runs_all = runs_raw.copy()
runs_all["best_test_final_next_activity_f1"] = (
    runs_all["best_test_final_next_activity_f1"]
    .combine_first(runs_all["best_test_final_next_activity_f1_macro"])
)
runs_all = runs_all.drop(columns=["best_test_final_next_activity_f1_macro"], errors="ignore")

for col in ["hidden_size", "n_layers", "n_heads"]:
    if col in runs_all.columns:
        runs_all[col] = pd.to_numeric(runs_all[col], errors="coerce")

def _fmt_int(v):
    return str(int(v)) if pd.notna(v) else "nan"

def _arch_label(df: pd.DataFrame) -> pd.Series:
    return (
        df["hidden_size"].map(_fmt_int)
        + "_"
        + df["n_layers"].map(_fmt_int)
        + "_"
        + df["n_heads"].map(_fmt_int)
    )

# Keep internal backbone distinct per source for separate aggregation,
# but display as <hidden>_<layers>_<heads> in plots/tables.
scratch_mask = runs_all["project"].astype(str).str.contains("nanogpt_scratch", na=False)
runs_all.loc[scratch_mask, "backbone"] = "scratch_" + _arch_label(runs_all.loc[scratch_mask])

distill_mask = runs_all["project"].astype(str).str.contains("distill", na=False)
runs_all.loc[distill_mask, "backbone"] = "distill_" + _arch_label(runs_all.loc[distill_mask])


def select_project_view(df: pd.DataFrame, view="all", include_baseline: bool = True) -> pd.DataFrame:
    proj = df["project"].astype(str)
    is_scratch = proj.str.contains("nanogpt_scratch", na=False)
    is_distill = proj.str.contains("distill", na=False)
    is_baseline = proj.eq("baseline-nep")
    is_finetune = proj.isin(PROJECTS_FINETUNE)

    source_masks = {
        "scratch": is_scratch,
        "distill": is_distill,
        "finetune": is_finetune,
    }

    if isinstance(view, (list, tuple, set)):
        selected = {str(v).strip().lower() for v in view if str(v).strip()}
    else:
        v = str(view).strip().lower()
        if v in {"all", "both+finetune", "scratch+distill+finetune"}:
            selected = {"scratch", "distill", "finetune"}
        elif v == "both":
            selected = {"scratch", "distill"}
        else:
            selected = {p.strip() for p in v.replace("+", ",").split(",") if p.strip()}

    invalid = selected - set(source_masks)
    if invalid:
        raise ValueError(
            "view must be one or a combination of: 'scratch', 'distill', 'finetune', 'both', 'all'"
        )

    mask = pd.Series(False, index=df.index)
    for src in selected:
        mask = mask | source_masks[src]

    if include_baseline:
        mask = mask | is_baseline

    return df.loc[mask].copy()


# Change these two values and re-run this cell + downstream graph/list cells.
PROJECT_VIEW = "all"  # e.g. "scratch", "distill", "finetune", "both", "all", "scratch+finetune"
INCLUDE_BASELINE_IN_VIEW = True

runs = select_project_view(runs_all, view=PROJECT_VIEW, include_baseline=INCLUDE_BASELINE_IN_VIEW)
print(f"PROJECT_VIEW={PROJECT_VIEW} | INCLUDE_BASELINE_IN_VIEW={INCLUDE_BASELINE_IN_VIEW} | runs={len(runs)}")
# Out:
# PROJECT_VIEW=all | INCLUDE_BASELINE_IN_VIEW=True | runs=1231

# %% [markdown]
# ## Print overview experiments
# ### -> Metric can be from ["best_test_final_next_activity_f1", "best_test_final_next_activity_acc"]

# %%
#METRIC = "best_test_final_next_activity_acc"
METRIC = "best_test_final_next_activity_f1"

for col in ["categorical_features", "continuous_features"]:
    if col in runs.columns:
        runs[col] = runs[col].astype(str)

GROUP_COLS = ["log", "backbone", "lr", "batch_size", "categorical_features", "continuous_features"]

EXTRA_COLS = ["project", "total_params", "trainable_params", "embedding_size"]
EXTRA_COLS = [c for c in EXTRA_COLS if c in runs.columns]  # only keep ones that exist

# Build df with everything we need
df = runs[GROUP_COLS + ["id", METRIC] + EXTRA_COLS].dropna(subset=[METRIC]).copy()
df[METRIC] = df[METRIC].astype(float)

# 1) Metric stats (ONLY from METRIC)
agg = (
    df.groupby(GROUP_COLS)[METRIC]
      .agg(["count", "mean", "std", "min", "max"])
      .rename(columns={
          "count": "n_runs",
          "mean": "acc_mean",
          "std": "acc_std",
          "min": "acc_min",
          "max": "acc_max",
      })
)

# 2) Add “descriptor” columns (not metric-related)
#    We assume these are constant within group; if not, we’ll detect it below.
descriptors = df.groupby(GROUP_COLS)[EXTRA_COLS].first() if EXTRA_COLS else None

# Optional: detect groups where descriptors are NOT constant
if EXTRA_COLS:
    nunique = df.groupby(GROUP_COLS)[EXTRA_COLS].nunique(dropna=False)
    bad = (nunique > 1).any(axis=1)
    if bad.any():
        print("Warning: some groups have varying descriptor values:")
        display(nunique[bad].reset_index())

# 3) Best run id per group (based on METRIC)
best_idx = df.groupby(GROUP_COLS)[METRIC].idxmax()
best_runs = df.loc[best_idx].set_index(GROUP_COLS)["id"].rename("best_run_id")

# 4) Combine
summary = agg
if descriptors is not None:
    summary = summary.join(descriptors)

summary = summary.join(best_runs).reset_index()
summary["n_runs"] = summary["n_runs"].astype(int)

for col in ["acc_mean", "acc_std", "acc_min", "acc_max"]:
    summary[col] = summary[col].map(lambda x: f"{x:.4f}")

summary = summary.sort_values(GROUP_COLS).reset_index(drop=True)

with pd.option_context("display.max_rows", None, "display.max_columns", None, "display.width", 200):
    display(summary)
# Out:
# Warning: some groups have varying descriptor values:
#                         log     backbone       lr  batch_size  \
# 0                     BPI12         gpt2  0.00500        64.0
# 1                     BPI12    gpt2-mini  0.00500        64.0
# 2                     BPI12   qwen3-0.6b  0.00005        64.0
# 3                     BPI12   qwen3-0.6b  0.00050        64.0
# 4                     BPI12   qwen3-0.6b  0.00500        64.0
# 5                     BPI12   qwen3-1.7b  0.00005        64.0
# 6                     BPI12   qwen3-1.7b  0.00050        64.0
# 7                     BPI12   qwen3-1.7b  0.00500        64.0
# 8                     BPI12     qwen3-4b  0.00005        64.0
# 9                     BPI12     qwen3-4b  0.00050        64.0
# 10                    BPI12     qwen3-4b  0.00500        64.0
# 11                    BPI15         gpt2  0.00500        64.0
# 12                    BPI17         gpt2  0.00500        64.0
# 13                    BPI17   gpt2-large  0.00050        64.0
# 14                    BPI17  gpt2-medium  0.00005        64.0
# 15                    BPI17  gpt2-medium  0.00050        64.0
# 16                    BPI17    gpt2-mini  0.00005        64.0
# 17                    BPI17   qwen3-0.6b  0.00050        64.0
# 18                    BPI17   qwen3-1.7b  0.00005        64.0
# 19                    BPI17   qwen3-1.7b  0.00050        64.0
# 20                    BPI19         gpt2  0.00005        64.0
# 21                    BPI19    gpt2-mini  0.00005        64.0
# 22  BPI20PrepaidTravelCosts    gpt2-mini  0.00500        64.0
# 23  BPI20PrepaidTravelCosts   qwen3-0.6b  0.00005        64.0
# 24  BPI20PrepaidTravelCosts   qwen3-0.6b  0.00050        64.0
# 25  BPI20PrepaidTravelCosts   qwen3-0.6b  0.00500        64.0
# 26  BPI20PrepaidTravelCosts   qwen3-1.7b  0.00005        64.0
# 27  BPI20PrepaidTravelCosts   qwen3-1.7b  0.00050        64.0
# 28  BPI20PrepaidTravelCosts   qwen3-1.7b  0.00500        64.0
# 29  BPI20PrepaidTravelCosts     qwen3-4b  0.00005        64.0
# 30  BPI20PrepaidTravelCosts     qwen3-4b  0.00050        64.0
# 31  BPI20PrepaidTravelCosts     qwen3-4b  0.00500        64.0
# 32   BPI20RequestForPayment         gpt2  0.00500        64.0
# 33    BPI20TravelPermitData         gpt2  0.00005        64.0
#
#    categorical_features   continuous_features  project  total_params  \
# 0          ['activity']  ['accumulated_time']        3             1
# 1          ['activity']  ['accumulated_time']        1             1
# 2          ['activity']  ['accumulated_time']        2             1
# 3          ['activity']  ['accumulated_time']        2             1
# 4          ['activity']  ['accumulated_time']        2             1
# 5          ['activity']  ['accumulated_time']        2             1
# 6          ['activity']  ['accumulated_time']        2             1
# 7          ['activity']  ['accumulated_time']        2             1
# 8          ['activity']  ['accumulated_time']        2             1
# 9          ['activity']  ['accumulated_time']        2             1
# 10         ['activity']  ['accumulated_time']        2             1
# 11         ['activity']  ['accumulated_time']        2             1
# 12         ['activity']  ['accumulated_time']        3             1
# 13         ['activity']  ['accumulated_time']        2             1
# 14         ['activity']  ['accumulated_time']        2             1
# 15         ['activity']  ['accumulated_time']        2             1
# 16         ['activity']  ['accumulated_time']        2             1
# 17         ['activity']  ['accumulated_time']        2             1
# 18         ['activity']  ['accumulated_time']        2             1
# 19         ['activity']  ['accumulated_time']        2             1
# 20         ['activity']  ['accumulated_time']        2             1
# 21         ['activity']  ['accumulated_time']        2             1
# 22         ['activity']  ['accumulated_time']        2             1
# 23         ['activity']  ['accumulated_time']        2             1
# 24         ['activity']  ['accumulated_time']        2             1
# 25         ['activity']  ['accumulated_time']        2             1
# 26         ['activity']  ['accumulated_time']        2             1
# 27         ['activity']  ['accumulated_time']        2             1
# 28         ['activity']  ['accumulated_time']        2             1
# 29         ['activity']  ['accumulated_time']        2             1
# 30         ['activity']  ['accumulated_time']        2             1
# 31         ['activity']  ['accumulated_time']        2             1
# 32         ['activity']  ['accumulated_time']        2             1
# 33         ['activity']  ['accumulated_time']        2             1
#
#     trainable_params  embedding_size
# 0                  1               2
# 1                  1               2
# 2                  1               1
# 3                  1               1
# 4                  1               1
# 5                  1               1
# 6                  1               1
# 7                  1               1
# 8                  1               1
# 9                  1               1
# 10                 1               1
# 11                 1               2
# 12                 1               2
# 13                 1               2
# 14                 1               2
# 15                 1               2
# 16                 1               2
# 17                 1               1
# 18                 1               1
# 19                 1               1
# 20                 1               1
# 21                 1               1
# 22                 1               2
# 23                 1               2
# 24                 1               1
# 25                 1               1
# 26                 1               2
# 27                 1               1
# 28                 1               1
# 29                 1               1
# 30                 1               1
# 31                 1               1
# 32                 1               2
# 33                 1               2
#                          log           backbone       lr  batch_size categorical_features   continuous_features  n_runs acc_mean acc_std acc_min acc_max                            project  \
# 0                      BPI12    distill_128_6_2  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.6724  0.0113  0.6603  0.6838        BPI12_lrz_distill_fixed_001
# 1                      BPI12    distill_256_6_4  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.6725  0.0117  0.6635  0.6858        BPI12_lrz_distill_fixed_001
# 2                      BPI12   distill_512_12_8  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.6773  0.0078  0.6651  0.6867        BPI12_lrz_distill_fixed_001
# 3                      BPI12    distill_512_6_8  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.6626  0.0355  0.6008  0.6869        BPI12_lrz_distill_fixed_001
# 4                      BPI12     distill_64_3_1  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.6752  0.0057  0.6689  0.6811        BPI12_lrz_distill_fixed_001
# 5                      BPI12     distill_64_6_1  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.6776  0.0040  0.6733  0.6829        BPI12_lrz_distill_fixed_001
# 6                      BPI12  distill_768_12_12  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.6591  0.0453  0.5816  0.6922        BPI12_lrz_distill_fixed_001
# 7                      BPI12               gpt2  0.00005        64.0         ['activity']  ['accumulated_time']       8   0.5343  0.0277  0.4836  0.5715                      BPI12_lrz_001
# 8                      BPI12               gpt2  0.00050        64.0         ['activity']  ['accumulated_time']       5   0.6338  0.0360  0.5776  0.6666                      BPI12_lrz_001
# 9                      BPI12               gpt2  0.00500        64.0         ['activity']  ['accumulated_time']      25   0.6674  0.0154  0.6381  0.7029                  BPI12_lrz_001_003
# 10                     BPI12         gpt2-large  0.00005        64.0         ['activity']  ['accumulated_time']       6   0.5978  0.0282  0.5490  0.6247                      BPI12_lrz_001
# 11                     BPI12         gpt2-large  0.00050        64.0         ['activity']  ['accumulated_time']       5   0.6307  0.0408  0.5591  0.6618                      BPI12_lrz_001
# 12                     BPI12         gpt2-large  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.6529  0.0248  0.6162  0.6715                      BPI12_lrz_001
# 13                     BPI12        gpt2-medium  0.00005        64.0         ['activity']  ['accumulated_time']       6   0.4088  0.2040  0.0050  0.5505                      BPI12_lrz_001
# 14                     BPI12        gpt2-medium  0.00050        64.0         ['activity']  ['accumulated_time']       5   0.6080  0.0508  0.5617  0.6877                      BPI12_lrz_001
# 15                     BPI12        gpt2-medium  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.6233  0.0446  0.5560  0.6712                      BPI12_lrz_001
# 16                     BPI12          gpt2-mini  0.00005        64.0         ['activity']  ['accumulated_time']       8   0.5841  0.0443  0.5380  0.6559                      BPI12_lrz_001
# 17                     BPI12          gpt2-mini  0.00050        64.0         ['activity']  ['accumulated_time']       5   0.6643  0.0247  0.6229  0.6873                      BPI12_lrz_001
# 18                     BPI12          gpt2-mini  0.00500        64.0         ['activity']  ['accumulated_time']       7   0.6746  0.0157  0.6555  0.6938                      BPI12_lrz_001
# 19                     BPI12            gpt2-xl  0.00005        64.0         ['activity']  ['accumulated_time']       4   0.3710  0.2082  0.0627  0.5131                      BPI12_lrz_001
# 20                     BPI12            gpt2-xl  0.00050        64.0         ['activity']  ['accumulated_time']       1   0.6224     nan  0.6224  0.6224                      BPI12_lrz_001
# 21                     BPI12            gpt2-xl  0.00500        64.0         ['activity']  ['accumulated_time']       4   0.6675  0.0066  0.6593  0.6750                      BPI12_lrz_001
# 22                     BPI12         qwen3-0.6b  0.00005        64.0         ['activity']  ['accumulated_time']       5   0.5909  0.0418  0.5333  0.6353                BPI12_spark_002_002
# 23                     BPI12         qwen3-0.6b  0.00050        64.0         ['activity']  ['accumulated_time']       5   0.6236  0.0659  0.5122  0.6762                BPI12_spark_002_002
# 24                     BPI12         qwen3-0.6b  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.6222  0.0464  0.5773  0.6809                BPI12_spark_002_002
# 25                     BPI12         qwen3-1.7b  0.00005        64.0         ['activity']  ['accumulated_time']       5   0.4176  0.0927  0.3074  0.5650                BPI12_spark_002_002
# 26                     BPI12         qwen3-1.7b  0.00050        64.0         ['activity']  ['accumulated_time']       5   0.5908  0.0442  0.5253  0.6497                BPI12_spark_002_002
# 27                     BPI12         qwen3-1.7b  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.6663  0.0091  0.6565  0.6772                BPI12_spark_002_002
# 28                     BPI12          qwen3-14b  0.00005        64.0         ['activity']  ['accumulated_time']       1   0.4247     nan  0.4247  0.4247                    BPI12_spark_002
# 29                     BPI12          qwen3-14b  0.00500        64.0         ['activity']  ['accumulated_time']       1   0.6761     nan  0.6761  0.6761                    BPI12_spark_002
# 30                     BPI12           qwen3-4b  0.00005        64.0         ['activity']  ['accumulated_time']       5   0.5392  0.0826  0.4422  0.6214                BPI12_spark_002_002
# 31                     BPI12           qwen3-4b  0.00050        64.0         ['activity']  ['accumulated_time']       5   0.6056  0.1010  0.4264  0.6665                BPI12_spark_002_002
# 32                     BPI12           qwen3-4b  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.6663  0.0114  0.6528  0.6812                BPI12_spark_002_002
# 33                     BPI12           qwen3-8b  0.00005        32.0         ['activity']  ['accumulated_time']       1   0.5806     nan  0.5806  0.5806                    BPI12_spark_002
# 34                     BPI12           qwen3-8b  0.00050        32.0         ['activity']  ['accumulated_time']       1   0.6290     nan  0.6290  0.6290                    BPI12_spark_002
# 35                     BPI12           qwen3-8b  0.00500        32.0         ['activity']  ['accumulated_time']       1   0.6670     nan  0.6670  0.6670                    BPI12_spark_002
# 36                     BPI12                rnn  0.00010        64.0         ['activity']  ['accumulated_time']      10   0.5226  0.0173  0.4934  0.5441     lstm_bpi12_size100_layers3_001
# 37                     BPI12    scratch_128_6_2  0.00010        64.0         ['activity']  ['accumulated_time']       5   0.6890  0.0052  0.6832  0.6952  BPI12_lrz_nanogpt_scratch_new_001
# 38                     BPI12    scratch_256_6_4  0.00010        64.0         ['activity']  ['accumulated_time']       5   0.6961  0.0050  0.6885  0.7009  BPI12_lrz_nanogpt_scratch_new_001
# 39                     BPI12   scratch_512_12_8  0.00010        64.0         ['activity']  ['accumulated_time']       5   0.6962  0.0061  0.6863  0.7016  BPI12_lrz_nanogpt_scratch_new_001
# 40                     BPI12    scratch_512_6_8  0.00010        64.0         ['activity']  ['accumulated_time']       5   0.6907  0.0068  0.6810  0.6985  BPI12_lrz_nanogpt_scratch_new_001
# 41                     BPI12     scratch_64_3_1  0.00010        64.0         ['activity']  ['accumulated_time']       5   0.6813  0.0107  0.6714  0.6934  BPI12_lrz_nanogpt_scratch_new_001
# 42                     BPI12     scratch_64_6_1  0.00010        64.0         ['activity']  ['accumulated_time']       5   0.6814  0.0039  0.6775  0.6864  BPI12_lrz_nanogpt_scratch_new_001
# 43                     BPI12  scratch_768_12_12  0.00010        64.0         ['activity']  ['accumulated_time']       5   0.6978  0.0077  0.6871  0.7055  BPI12_lrz_nanogpt_scratch_new_001
# 44                     BPI15   distill_512_12_8  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.0216  0.0338  0.0009  0.0814        BPI15_lrz_distill_fixed_001
# 45                     BPI15    distill_512_6_8  0.00500        64.0         ['activity']  ['accumulated_time']       1   0.0010     nan  0.0010  0.0010        BPI15_lrz_distill_fixed_001
# 46                     BPI15  distill_768_12_12  0.00500        64.0         ['activity']  ['accumulated_time']       4   0.0092  0.0086  0.0002  0.0206        BPI15_lrz_distill_fixed_001
# 47                     BPI15               gpt2  0.00005        64.0         ['activity']  ['accumulated_time']       5   0.0139  0.0039  0.0108  0.0206                      BPI15_lrz_001
# 48                     BPI15               gpt2  0.00050        64.0         ['activity']  ['accumulated_time']       5   0.0913  0.0111  0.0772  0.1027                      BPI15_lrz_001
# 49                     BPI15               gpt2  0.00500        64.0         ['activity']  ['accumulated_time']      15   0.1102  0.0096  0.0915  0.1253                  BPI15_lrz_002_001
# 50                     BPI15         gpt2-large  0.00005        64.0         ['activity']  ['accumulated_time']       5   0.0084  0.0070  0.0009  0.0159                      BPI15_lrz_001
# 51                     BPI15         gpt2-large  0.00050        64.0         ['activity']  ['accumulated_time']       5   0.0649  0.0507  0.0089  0.1047                      BPI15_lrz_001
# 52                     BPI15         gpt2-large  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.1038  0.0053  0.0988  0.1121                      BPI15_lrz_001
# 53                     BPI15        gpt2-medium  0.00005        64.0         ['activity']  ['accumulated_time']       5   0.0028  0.0024  0.0002  0.0063                      BPI15_lrz_001
# 54                     BPI15        gpt2-medium  0.00050        64.0         ['activity']  ['accumulated_time']       5   0.0023  0.0014  0.0005  0.0042                      BPI15_lrz_001
# 55                     BPI15        gpt2-medium  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.1039  0.0058  0.0968  0.1118                      BPI15_lrz_001
# 56                     BPI15          gpt2-mini  0.00005        64.0         ['activity']  ['accumulated_time']       5   0.0278  0.0089  0.0203  0.0429                      BPI15_lrz_001
# 57                     BPI15          gpt2-mini  0.00050        64.0         ['activity']  ['accumulated_time']       5   0.1000  0.0064  0.0899  0.1050                      BPI15_lrz_001
# 58                     BPI15          gpt2-mini  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.1098  0.0026  0.1072  0.1135                      BPI15_lrz_001
# 59                     BPI15            gpt2-xl  0.00005        64.0         ['activity']  ['accumulated_time']       4   0.0062  0.0038  0.0015  0.0105                      BPI15_lrz_001
# 60                     BPI15            gpt2-xl  0.00050        64.0         ['activity']  ['accumulated_time']       4   0.0461  0.0446  0.0076  0.0928                      BPI15_lrz_001
# 61                     BPI15            gpt2-xl  0.00500        64.0         ['activity']  ['accumulated_time']       4   0.0998  0.0051  0.0951  0.1069                      BPI15_lrz_001
# 62                     BPI15         qwen3-0.6b  0.00005        64.0         ['activity']  ['accumulated_time']       5   0.0639  0.0279  0.0163  0.0835                      BPI15_lrz_002
# 63                     BPI15         qwen3-0.6b  0.00050        64.0         ['activity']  ['accumulated_time']       5   0.0835  0.0055  0.0751  0.0887                      BPI15_lrz_002
# 64                     BPI15         qwen3-0.6b  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.0862  0.0086  0.0743  0.0974                      BPI15_lrz_002
# 65                     BPI15         qwen3-1.7b  0.00005        64.0         ['activity']  ['accumulated_time']       5   0.0128  0.0164  0.0021  0.0418                      BPI15_lrz_002
# 66                     BPI15         qwen3-1.7b  0.00050        64.0         ['activity']  ['accumulated_time']       5   0.0264  0.0200  0.0059  0.0524                      BPI15_lrz_002
# 67                     BPI15         qwen3-1.7b  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.0840  0.0088  0.0709  0.0951                      BPI15_lrz_002
# 68                     BPI15           qwen3-4b  0.00005        64.0         ['activity']  ['accumulated_time']       4   0.0109  0.0032  0.0061  0.0129                      BPI15_lrz_002
# 69                     BPI15           qwen3-4b  0.00050        64.0         ['activity']  ['accumulated_time']       5   0.0599  0.0230  0.0196  0.0753                      BPI15_lrz_002
# 70                     BPI15           qwen3-4b  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.0899  0.0046  0.0851  0.0952                      BPI15_lrz_002
# 71                     BPI15    scratch_128_6_2  0.00010        64.0         ['activity']  ['accumulated_time']       5   0.0976  0.0044  0.0920  0.1014  BPI15_lrz_nanogpt_scratch_new_001
# 72                     BPI15    scratch_256_6_4  0.00010        64.0         ['activity']  ['accumulated_time']       5   0.1053  0.0037  0.1014  0.1104  BPI15_lrz_nanogpt_scratch_new_001
# 73                     BPI15   scratch_512_12_8  0.00010        64.0         ['activity']  ['accumulated_time']       5   0.1019  0.0052  0.0968  0.1090  BPI15_lrz_nanogpt_scratch_new_001
# 74                     BPI15    scratch_512_6_8  0.00010        64.0         ['activity']  ['accumulated_time']       5   0.1037  0.0064  0.0971  0.1114  BPI15_lrz_nanogpt_scratch_new_001
# 75                     BPI15     scratch_64_3_1  0.00010        64.0         ['activity']  ['accumulated_time']       5   0.0751  0.0038  0.0707  0.0805  BPI15_lrz_nanogpt_scratch_new_001
# 76                     BPI15     scratch_64_6_1  0.00010        64.0         ['activity']  ['accumulated_time']       5   0.0763  0.0039  0.0722  0.0825  BPI15_lrz_nanogpt_scratch_new_001
# 77                     BPI15  scratch_768_12_12  0.00010        64.0         ['activity']  ['accumulated_time']       5   0.0892  0.0048  0.0837  0.0931  BPI15_lrz_nanogpt_scratch_new_001
# 78                     BPI17    distill_128_6_2  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.6610  0.0064  0.6530  0.6676        BPI17_lrz_distill_fixed_001
# 79                     BPI17    distill_256_6_4  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.6607  0.0119  0.6525  0.6816        BPI17_lrz_distill_fixed_001
# 80                     BPI17   distill_512_12_8  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.6606  0.0085  0.6544  0.6735        BPI17_lrz_distill_fixed_001
# 81                     BPI17    distill_512_6_8  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.6596  0.0089  0.6464  0.6677        BPI17_lrz_distill_fixed_001
# 82                     BPI17     distill_64_3_1  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.6598  0.0046  0.6541  0.6665        BPI17_lrz_distill_fixed_001
# 83                     BPI17     distill_64_6_1  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.6593  0.0072  0.6479  0.6664        BPI17_lrz_distill_fixed_001
# 84                     BPI17  distill_768_12_12  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.6653  0.0033  0.6617  0.6685        BPI17_lrz_distill_fixed_001
# 85                     BPI17               gpt2  0.00005        64.0         ['activity']  ['accumulated_time']       5   0.6199  0.0114  0.6016  0.6304                      BPI17_lrz_001
# 86                     BPI17               gpt2  0.00050        64.0         ['activity']  ['accumulated_time']       5   0.6427  0.0111  0.6289  0.6554                      BPI17_lrz_001
# 87                     BPI17               gpt2  0.00500        64.0         ['activity']  ['accumulated_time']      20   0.6567  0.0143  0.6229  0.6762                  BPI17_lrz_002_002
# 88                     BPI17         gpt2-large  0.00005        64.0         ['activity']  ['accumulated_time']       5   0.6357  0.0070  0.6281  0.6457                BPI17_spark_002_001
# 89                     BPI17         gpt2-large  0.00050        64.0         ['activity']  ['accumulated_time']       5   0.6528  0.0051  0.6459  0.6591                BPI17_spark_002_001
# 90                     BPI17         gpt2-large  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.6578  0.0169  0.6391  0.6814                      BPI17_lrz_001
# 91                     BPI17        gpt2-medium  0.00005        64.0         ['activity']  ['accumulated_time']       5   0.5969  0.0155  0.5841  0.6217                BPI17_spark_002_001
# 92                     BPI17        gpt2-medium  0.00050        64.0         ['activity']  ['accumulated_time']       5   0.6234  0.0307  0.5777  0.6565                BPI17_spark_002_001
# 93                     BPI17        gpt2-medium  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.6279  0.0124  0.6107  0.6437                      BPI17_lrz_001
# 94                     BPI17          gpt2-mini  0.00005        64.0         ['activity']  ['accumulated_time']       5   0.5982  0.0634  0.4850  0.6304                BPI17_spark_002_001
# 95                     BPI17          gpt2-mini  0.00050        64.0         ['activity']  ['accumulated_time']       5   0.6314  0.0078  0.6197  0.6411                      BPI17_lrz_001
# 96                     BPI17          gpt2-mini  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.6627  0.0044  0.6579  0.6683                      BPI17_lrz_001
# 97                     BPI17            gpt2-xl  0.00050        64.0         ['activity']  ['accumulated_time']       1   0.6224     nan  0.6224  0.6224                      BPI17_lrz_001
# 98                     BPI17            gpt2-xl  0.00500        64.0         ['activity']  ['accumulated_time']       1   0.6452     nan  0.6452  0.6452                      BPI17_lrz_001
# 99                     BPI17         qwen3-0.6b  0.00005        64.0         ['activity']  ['accumulated_time']       5   0.6254  0.0247  0.5873  0.6489                      BPI17_lrz_002
# 100                    BPI17         qwen3-0.6b  0.00050        64.0         ['activity']  ['accumulated_time']       5   0.6523  0.0139  0.6392  0.6717                BPI17_spark_002_001
# 101                    BPI17         qwen3-0.6b  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.6562  0.0131  0.6388  0.6711                BPI17_spark_002_001
# 102                    BPI17         qwen3-1.7b  0.00005        64.0         ['activity']  ['accumulated_time']       5   0.5909  0.0614  0.4875  0.6410                BPI17_spark_002_001
# 103                    BPI17         qwen3-1.7b  0.00050        64.0         ['activity']  ['accumulated_time']       5   0.6116  0.0570  0.5112  0.6531                BPI17_spark_002_001
# 104                    BPI17         qwen3-1.7b  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.6663  0.0257  0.6237  0.6842                BPI17_spark_002_001
# 105                    BPI17           qwen3-4b  0.00005        64.0         ['activity']  ['accumulated_time']       1   0.6083     nan  0.6083  0.6083                BPI17_spark_002_002
# 106                    BPI17           qwen3-4b  0.00050        64.0         ['activity']  ['accumulated_time']       1   0.6703     nan  0.6703  0.6703                BPI17_spark_002_002
# 107                    BPI17           qwen3-4b  0.00500        64.0         ['activity']  ['accumulated_time']       1   0.6771     nan  0.6771  0.6771                BPI17_spark_002_002
# 108                    BPI17    scratch_128_6_2  0.00010        64.0         ['activity']  ['accumulated_time']       5   0.6724  0.0055  0.6634  0.6768  BPI17_lrz_nanogpt_scratch_new_001
# 109                    BPI17    scratch_256_6_4  0.00010        64.0         ['activity']  ['accumulated_time']       5   0.6782  0.0071  0.6722  0.6897  BPI17_lrz_nanogpt_scratch_new_001
# 110                    BPI17   scratch_512_12_8  0.00010        64.0         ['activity']  ['accumulated_time']       5   0.6859  0.0075  0.6744  0.6917  BPI17_lrz_nanogpt_scratch_new_001
# 111                    BPI17    scratch_512_6_8  0.00010        64.0         ['activity']  ['accumulated_time']       5   0.6776  0.0088  0.6694  0.6896  BPI17_lrz_nanogpt_scratch_new_001
# 112                    BPI17     scratch_64_3_1  0.00010        64.0         ['activity']  ['accumulated_time']       5   0.6579  0.0049  0.6523  0.6656  BPI17_lrz_nanogpt_scratch_new_001
# 113                    BPI17     scratch_64_6_1  0.00010        64.0         ['activity']  ['accumulated_time']       5   0.6600  0.0107  0.6500  0.6757  BPI17_lrz_nanogpt_scratch_new_001
# 114                    BPI17  scratch_768_12_12  0.00010        64.0         ['activity']  ['accumulated_time']       5   0.6781  0.0055  0.6716  0.6853  BPI17_lrz_nanogpt_scratch_new_001
# 115                    BPI19    distill_128_6_2  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.2063  0.0120  0.1863  0.2185        BPI19_lrz_distill_fixed_001
# 116                    BPI19    distill_256_6_4  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.2209  0.0235  0.1870  0.2519        BPI19_lrz_distill_fixed_001
# 117                    BPI19   distill_512_12_8  0.00500        64.0         ['activity']  ['accumulated_time']       3   0.1882  0.0122  0.1795  0.2022        BPI19_lrz_distill_fixed_001
# 118                    BPI19    distill_512_6_8  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.2029  0.0317  0.1715  0.2521        BPI19_lrz_distill_fixed_001
# 119                    BPI19     distill_64_3_1  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.2024  0.0115  0.1864  0.2155        BPI19_lrz_distill_fixed_001
# 120                    BPI19     distill_64_6_1  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.2018  0.0118  0.1835  0.2161        BPI19_lrz_distill_fixed_001
# 121                    BPI19  distill_768_12_12  0.00500        64.0         ['activity']  ['accumulated_time']       3   0.2047  0.0331  0.1789  0.2421        BPI19_lrz_distill_fixed_001
# 122                    BPI19               gpt2  0.00005        64.0         ['activity']  ['accumulated_time']      12   0.1511  0.0118  0.1408  0.1751                  BPI19_lrz_002_002
# 123                    BPI19               gpt2  0.00050        64.0         ['activity']  ['accumulated_time']       1   0.1876     nan  0.1876  0.1876                  BPI19_lrz_002_002
# 124                    BPI19        gpt2-medium  0.00005        32.0         ['activity']  ['accumulated_time']       1   0.1081     nan  0.1081  0.1081                  BPI19_lrz_002_002
# 125                    BPI19        gpt2-medium  0.00005        64.0         ['activity']  ['accumulated_time']       1   0.0943     nan  0.0943  0.0943                      BPI19_lrz_001
# 126                    BPI19          gpt2-mini  0.00005        64.0         ['activity']  ['accumulated_time']      13   0.1633  0.0270  0.1295  0.1904                  BPI19_lrz_002_002
# 127                    BPI19          gpt2-mini  0.00050        64.0         ['activity']  ['accumulated_time']       1   0.2409     nan  0.2409  0.2409                  BPI19_lrz_002_002
# 128                    BPI19         qwen3-0.6b  0.00005        64.0         ['activity']  ['accumulated_time']       3   0.1771  0.0105  0.1657  0.1865                      BPI19_lrz_002
# 129                    BPI19         qwen3-0.6b  0.00050        64.0         ['activity']  ['accumulated_time']       1   0.2357     nan  0.2357  0.2357                      BPI19_lrz_002
# 130                    BPI19   scratch_512_12_8  0.00010        64.0         ['activity']  ['accumulated_time']       4   0.2923  0.0091  0.2831  0.3048  BPI19_lrz_nanogpt_scratch_new_001
# 131                    BPI19  scratch_768_12_12  0.00010        64.0         ['activity']  ['accumulated_time']       5   0.2871  0.0072  0.2778  0.2969  BPI19_lrz_nanogpt_scratch_new_001
# 132  BPI20PrepaidTravelCosts    distill_128_6_2  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.5577  0.0104  0.5457  0.5742     BPI20PTC_lrz_distill_fixed_001
# 133  BPI20PrepaidTravelCosts    distill_256_6_4  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.4804  0.0571  0.4324  0.5711     BPI20PTC_lrz_distill_fixed_001
# 134  BPI20PrepaidTravelCosts   distill_512_12_8  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.4723  0.0629  0.3941  0.5692     BPI20PTC_lrz_distill_fixed_001
# 135  BPI20PrepaidTravelCosts    distill_512_6_8  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.4608  0.0394  0.3974  0.4987     BPI20PTC_lrz_distill_fixed_001
# 136  BPI20PrepaidTravelCosts     distill_64_3_1  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.5713  0.0048  0.5660  0.5756     BPI20PTC_lrz_distill_fixed_001
# 137  BPI20PrepaidTravelCosts     distill_64_6_1  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.5759  0.0061  0.5707  0.5864     BPI20PTC_lrz_distill_fixed_001
# 138  BPI20PrepaidTravelCosts  distill_768_12_12  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.4185  0.0516  0.3635  0.4827     BPI20PTC_lrz_distill_fixed_001
# 139  BPI20PrepaidTravelCosts               gpt2  0.00005        64.0         ['activity']  ['accumulated_time']       5   0.4155  0.0455  0.3469  0.4720                  BPI20_PTC_lrz_001
# 140  BPI20PrepaidTravelCosts               gpt2  0.00050        64.0         ['activity']  ['accumulated_time']       5   0.5342  0.0407  0.4631  0.5618                  BPI20_PTC_lrz_001
# 141  BPI20PrepaidTravelCosts               gpt2  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.5276  0.0175  0.5052  0.5482                  BPI20_PTC_lrz_001
# 142  BPI20PrepaidTravelCosts         gpt2-large  0.00005        64.0         ['activity']  ['accumulated_time']       5   0.2086  0.1816  0.0106  0.3805                  BPI20_PTC_lrz_001
# 143  BPI20PrepaidTravelCosts         gpt2-large  0.00050        64.0         ['activity']  ['accumulated_time']       5   0.5221  0.0203  0.4921  0.5419                  BPI20_PTC_lrz_001
# 144  BPI20PrepaidTravelCosts         gpt2-large  0.00500        64.0         ['activity']  ['accumulated_time']       4   0.5224  0.0246  0.4964  0.5505                  BPI20_PTC_lrz_001
# 145  BPI20PrepaidTravelCosts        gpt2-medium  0.00005        64.0         ['activity']  ['accumulated_time']       5   0.2086  0.0941  0.0859  0.2832                  BPI20_PTC_lrz_001
# 146  BPI20PrepaidTravelCosts        gpt2-medium  0.00050        64.0         ['activity']  ['accumulated_time']       5   0.5047  0.0130  0.4910  0.5217                  BPI20_PTC_lrz_001
# 147  BPI20PrepaidTravelCosts        gpt2-medium  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.5045  0.0665  0.3866  0.5431                  BPI20_PTC_lrz_001
# 148  BPI20PrepaidTravelCosts          gpt2-mini  0.00005        64.0         ['activity']  ['accumulated_time']       5   0.4525  0.0441  0.4110  0.5049                  BPI20_PTC_lrz_001
# 149  BPI20PrepaidTravelCosts          gpt2-mini  0.00050        64.0         ['activity']  ['accumulated_time']       5   0.5401  0.0242  0.4970  0.5543                  BPI20_PTC_lrz_001
# 150  BPI20PrepaidTravelCosts          gpt2-mini  0.00500        64.0         ['activity']  ['accumulated_time']      15   0.5510  0.0114  0.5330  0.5707                  BPI20_lrz_002_002
# 151  BPI20PrepaidTravelCosts            gpt2-xl  0.00005        64.0         ['activity']  ['accumulated_time']       4   0.3124  0.1516  0.1058  0.4324                  BPI20_PTC_lrz_001
# 152  BPI20PrepaidTravelCosts            gpt2-xl  0.00050        64.0         ['activity']  ['accumulated_time']       4   0.5352  0.0187  0.5101  0.5547                  BPI20_PTC_lrz_001
# 153  BPI20PrepaidTravelCosts            gpt2-xl  0.00500        64.0         ['activity']  ['accumulated_time']       4   0.5255  0.0228  0.4981  0.5539                  BPI20_PTC_lrz_001
# 154  BPI20PrepaidTravelCosts         qwen3-0.6b  0.00005        64.0         ['activity']  ['accumulated_time']      11   0.4521  0.0665  0.3100  0.5386                  BPI20_PTC_lrz_002
# 155  BPI20PrepaidTravelCosts         qwen3-0.6b  0.00050        64.0         ['activity']  ['accumulated_time']      10   0.5254  0.0210  0.4752  0.5527                  BPI20_PTC_lrz_002
# 156  BPI20PrepaidTravelCosts         qwen3-0.6b  0.00500        64.0         ['activity']  ['accumulated_time']      10   0.5378  0.0212  0.5101  0.5711                  BPI20_PTC_lrz_002
# 157  BPI20PrepaidTravelCosts         qwen3-1.7b  0.00005        64.0         ['activity']  ['accumulated_time']      10   0.3958  0.0929  0.1706  0.4865                  BPI20_PTC_lrz_002
# 158  BPI20PrepaidTravelCosts         qwen3-1.7b  0.00050        64.0         ['activity']  ['accumulated_time']      10   0.4778  0.0412  0.3942  0.5241                  BPI20_PTC_lrz_002
# 159  BPI20PrepaidTravelCosts         qwen3-1.7b  0.00500        64.0         ['activity']  ['accumulated_time']      10   0.5320  0.0251  0.4911  0.5646                  BPI20_PTC_lrz_002
# 160  BPI20PrepaidTravelCosts           qwen3-4b  0.00005        64.0         ['activity']  ['accumulated_time']      10   0.4515  0.0494  0.3440  0.5011                  BPI20_PTC_lrz_002
# 161  BPI20PrepaidTravelCosts           qwen3-4b  0.00050        64.0         ['activity']  ['accumulated_time']      10   0.5063  0.0294  0.4555  0.5562                  BPI20_PTC_lrz_002
# 162  BPI20PrepaidTravelCosts           qwen3-4b  0.00500        64.0         ['activity']  ['accumulated_time']      10   0.5298  0.0180  0.4967  0.5525                  BPI20_PTC_lrz_002
# 163  BPI20PrepaidTravelCosts           qwen3-8b  0.00005        32.0         ['activity']  ['accumulated_time']       5   0.4304  0.0523  0.3453  0.4813                BPI20_PTC_spark_001
# 164  BPI20PrepaidTravelCosts           qwen3-8b  0.00050        32.0         ['activity']  ['accumulated_time']       5   0.4370  0.0768  0.3445  0.5445                BPI20_PTC_spark_001
# 165  BPI20PrepaidTravelCosts           qwen3-8b  0.00500        32.0         ['activity']  ['accumulated_time']       5   0.5158  0.0306  0.4746  0.5584                BPI20_PTC_spark_001
# 166   BPI20RequestForPayment    distill_128_6_2  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.4666  0.0336  0.4498  0.5266     BPI20RFP_lrz_distill_fixed_001
# 167   BPI20RequestForPayment    distill_256_6_4  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.4679  0.0260  0.4498  0.5131     BPI20RFP_lrz_distill_fixed_001
# 168   BPI20RequestForPayment   distill_512_12_8  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.4704  0.0274  0.4460  0.5058     BPI20RFP_lrz_distill_fixed_001
# 169   BPI20RequestForPayment    distill_512_6_8  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.4654  0.0130  0.4509  0.4758     BPI20RFP_lrz_distill_fixed_001
# 170   BPI20RequestForPayment     distill_64_3_1  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.5010  0.0342  0.4520  0.5255     BPI20RFP_lrz_distill_fixed_001
# 171   BPI20RequestForPayment     distill_64_6_1  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.4821  0.0393  0.4524  0.5255     BPI20RFP_lrz_distill_fixed_001
# 172   BPI20RequestForPayment  distill_768_12_12  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.4636  0.0220  0.4436  0.4951     BPI20RFP_lrz_distill_fixed_001
# 173   BPI20RequestForPayment               gpt2  0.00005        64.0         ['activity']  ['accumulated_time']       5   0.4234  0.0158  0.4061  0.4355                  BPI20_RFP_lrz_001
# 174   BPI20RequestForPayment               gpt2  0.00050        64.0         ['activity']  ['accumulated_time']       5   0.5066  0.0305  0.4532  0.5267                  BPI20_RFP_lrz_001
# 175   BPI20RequestForPayment               gpt2  0.00500        64.0         ['activity']  ['accumulated_time']      20   0.4970  0.0374  0.4079  0.5329                  BPI20_lrz_002_002
# 176   BPI20RequestForPayment         gpt2-large  0.00005        64.0         ['activity']  ['accumulated_time']       5   0.4310  0.0249  0.3934  0.4529                  BPI20_RFP_lrz_001
# 177   BPI20RequestForPayment         gpt2-large  0.00050        64.0         ['activity']  ['accumulated_time']       5   0.4927  0.0325  0.4477  0.5253                  BPI20_RFP_lrz_001
# 178   BPI20RequestForPayment         gpt2-large  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.5168  0.0167  0.4975  0.5391                  BPI20_RFP_lrz_001
# 179   BPI20RequestForPayment        gpt2-medium  0.00005        64.0         ['activity']  ['accumulated_time']       5   0.2584  0.1838  0.0269  0.4409                  BPI20_RFP_lrz_001
# 180   BPI20RequestForPayment        gpt2-medium  0.00050        64.0         ['activity']  ['accumulated_time']       5   0.4336  0.0489  0.3836  0.4866                  BPI20_RFP_lrz_001
# 181   BPI20RequestForPayment        gpt2-medium  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.4959  0.0161  0.4792  0.5124                  BPI20_RFP_lrz_001
# 182   BPI20RequestForPayment          gpt2-mini  0.00005        64.0         ['activity']  ['accumulated_time']       5   0.4966  0.0313  0.4438  0.5211                  BPI20_RFP_lrz_001
# 183   BPI20RequestForPayment          gpt2-mini  0.00050        64.0         ['activity']  ['accumulated_time']       5   0.5046  0.0038  0.4980  0.5076                  BPI20_RFP_lrz_001
# 184   BPI20RequestForPayment          gpt2-mini  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.5096  0.0202  0.4878  0.5336                  BPI20_RFP_lrz_001
# 185   BPI20RequestForPayment            gpt2-xl  0.00005        64.0         ['activity']  ['accumulated_time']       4   0.4447  0.0074  0.4344  0.4517                  BPI20_RFP_lrz_001
# 186   BPI20RequestForPayment            gpt2-xl  0.00050        64.0         ['activity']  ['accumulated_time']       4   0.4893  0.0290  0.4507  0.5126                  BPI20_RFP_lrz_001
# 187   BPI20RequestForPayment            gpt2-xl  0.00500        64.0         ['activity']  ['accumulated_time']       4   0.5093  0.0182  0.4873  0.5288                  BPI20_RFP_lrz_001
# 188   BPI20RequestForPayment         qwen3-0.6b  0.00005        64.0         ['activity']  ['accumulated_time']       5   0.4966  0.0204  0.4687  0.5196                  BPI20_RFP_lrz_002
# 189   BPI20RequestForPayment         qwen3-0.6b  0.00050        64.0         ['activity']  ['accumulated_time']       5   0.5156  0.0196  0.4936  0.5322                  BPI20_RFP_lrz_002
# 190   BPI20RequestForPayment         qwen3-0.6b  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.5114  0.0188  0.4907  0.5318                  BPI20_RFP_lrz_002
# 191   BPI20RequestForPayment         qwen3-1.7b  0.00005        64.0         ['activity']  ['accumulated_time']       5   0.4205  0.0428  0.3769  0.4901                  BPI20_RFP_lrz_002
# 192   BPI20RequestForPayment         qwen3-1.7b  0.00050        64.0         ['activity']  ['accumulated_time']       5   0.4874  0.0488  0.4059  0.5253                  BPI20_RFP_lrz_002
# 193   BPI20RequestForPayment         qwen3-1.7b  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.5123  0.0204  0.4796  0.5277                  BPI20_RFP_lrz_002
# 194   BPI20RequestForPayment           qwen3-4b  0.00005        64.0         ['activity']  ['accumulated_time']       5   0.4653  0.0135  0.4517  0.4832                  BPI20_RFP_lrz_002
# 195   BPI20RequestForPayment           qwen3-4b  0.00050        64.0         ['activity']  ['accumulated_time']       4   0.4813  0.0495  0.4106  0.5240                  BPI20_RFP_lrz_002
# 196   BPI20RequestForPayment           qwen3-4b  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.4993  0.0351  0.4456  0.5363                  BPI20_RFP_lrz_002
# 197    BPI20TravelPermitData    distill_128_6_2  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.4793  0.0058  0.4755  0.4894     BPI20TPD_lrz_distill_fixed_001
# 198    BPI20TravelPermitData    distill_256_6_4  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.4674  0.0141  0.4447  0.4823     BPI20TPD_lrz_distill_fixed_001
# 199    BPI20TravelPermitData   distill_512_12_8  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.4787  0.0076  0.4670  0.4865     BPI20TPD_lrz_distill_fixed_001
# 200    BPI20TravelPermitData    distill_512_6_8  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.4813  0.0138  0.4633  0.4953     BPI20TPD_lrz_distill_fixed_001
# 201    BPI20TravelPermitData     distill_64_3_1  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.4742  0.0098  0.4609  0.4877     BPI20TPD_lrz_distill_fixed_001
# 202    BPI20TravelPermitData     distill_64_6_1  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.4720  0.0074  0.4614  0.4785     BPI20TPD_lrz_distill_fixed_001
# 203    BPI20TravelPermitData  distill_768_12_12  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.4279  0.0696  0.3406  0.4796     BPI20TPD_lrz_distill_fixed_001
# 204    BPI20TravelPermitData               gpt2  0.00005        64.0         ['activity']  ['accumulated_time']      10   0.3695  0.0129  0.3395  0.3897                  BPI20_lrz_002_002
# 205    BPI20TravelPermitData               gpt2  0.00050        64.0         ['activity']  ['accumulated_time']       5   0.3688  0.0361  0.3239  0.4099                  BPI20_TPD_lrz_001
# 206    BPI20TravelPermitData               gpt2  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.3778  0.0091  0.3640  0.3888                  BPI20_TPD_lrz_001
# 207    BPI20TravelPermitData         gpt2-large  0.00005        64.0         ['activity']  ['accumulated_time']       5   0.3396  0.0366  0.2849  0.3748                  BPI20_TPD_lrz_001
# 208    BPI20TravelPermitData         gpt2-large  0.00050        64.0         ['activity']  ['accumulated_time']       5   0.3706  0.0177  0.3457  0.3881                  BPI20_TPD_lrz_001
# 209    BPI20TravelPermitData         gpt2-large  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.3648  0.0370  0.3077  0.4072                  BPI20_TPD_lrz_001
# 210    BPI20TravelPermitData        gpt2-medium  0.00005        64.0         ['activity']  ['accumulated_time']       5   0.2433  0.1259  0.0358  0.3396                  BPI20_TPD_lrz_001
# 211    BPI20TravelPermitData        gpt2-medium  0.00050        64.0         ['activity']  ['accumulated_time']       5   0.3796  0.0254  0.3408  0.4052                  BPI20_TPD_lrz_001
# 212    BPI20TravelPermitData        gpt2-medium  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.3790  0.0191  0.3515  0.4053                  BPI20_TPD_lrz_001
# 213    BPI20TravelPermitData          gpt2-mini  0.00005        64.0         ['activity']  ['accumulated_time']       5   0.3765  0.0262  0.3423  0.3990                  BPI20_TPD_lrz_001
# 214    BPI20TravelPermitData          gpt2-mini  0.00050        64.0         ['activity']  ['accumulated_time']       5   0.3872  0.0259  0.3421  0.4041                  BPI20_TPD_lrz_001
# 215    BPI20TravelPermitData          gpt2-mini  0.00500        64.0         ['activity']  ['accumulated_time']       5   0.4075  0.0245  0.3655  0.4270                  BPI20_TPD_lrz_001
# 216    BPI20TravelPermitData            gpt2-xl  0.00005        64.0         ['activity']  ['accumulated_time']       4   0.3605  0.0223  0.3386  0.3899                  BPI20_TPD_lrz_001
# ...
# 233    BPI20TravelPermitData           qwen3-8b  0.00050        32.0         ['activity']  ['accumulated_time']       5   0.3436  0.0440  0.2892  0.3996                BPI20_TPD_spark_001
# 234    BPI20TravelPermitData           qwen3-8b  0.00500        32.0         ['activity']  ['accumulated_time']       1   0.3691     nan  0.3691  0.3691                BPI20_TPD_spark_001
#
#      total_params  trainable_params  embedding_size best_run_id
# 0    1.332391e+06         1332391.0             NaN    jw7igsob
# 1    5.024039e+06         5024039.0             NaN    r34fp8v3
# 2    3.839953e+07        38399527.0             NaN    n874h7r2
# 3    1.948522e+07        19485223.0             NaN    gj12qbvt
# 4    2.213510e+05          221351.0             NaN    9g77td9j
# 5    3.713030e+05          371303.0             NaN    hv8myqd2
# 6    8.591082e+07        85910823.0             NaN    50yci2av
# 7    1.245044e+08           64551.0             NaN    c947ecdg
# 8    1.245044e+08           64551.0             NaN    jyb5k3cq
# 9    1.245044e+08           64551.0           768.0    dp0zs0q6
# 10   7.741376e+08          107559.0             NaN    n4otavte
# 11   7.741376e+08          107559.0             NaN    hq2i1u6p
# 12   7.741376e+08          107559.0             NaN    9fx0jpek
# 13   3.549092e+08           86055.0             NaN    ig5x2z3i
# 14   3.549092e+08           86055.0             NaN    512b6mnw
# 15   3.549092e+08           86055.0             NaN    a56yup1h
# 16   3.864734e+07           43047.0             NaN    jxt1xv0n
# 17   3.864734e+07           43047.0             NaN    vyp7dqs1
# 18   3.864734e+07           43047.0           512.0    nk564mb4
# 19   1.557746e+09          134439.0             NaN    94pntaod
# 20   1.557746e+09          134439.0             NaN    3itwdv79
# 21   1.557746e+09          134439.0             NaN    rcltgs2i
# 22   5.961360e+08          151591.0          1024.0    dhkqz419
# 23   5.961360e+08          151591.0          1024.0    5x3fy6nt
# 24   5.961360e+08          151591.0          1024.0    sd01vly9
# 25   1.720747e+09          295975.0          2048.0    w4v51kr8
# 26   1.720747e+09          295975.0          2048.0    2lowoz1w
# 27   1.720747e+09          295975.0          2048.0    wap624z1
# 28   1.399082e+10          855079.0          5120.0    gevt9gv7
# 29   1.399082e+10          855079.0          5120.0    p3vdwx71
# 30   4.022683e+09          411175.0          2560.0    cl93vb2d
# 31   4.022683e+09          411175.0          2560.0    o3986t7l
# 32   4.022683e+09          411175.0          2560.0    58hcflzv
# 33   7.568750e+09          652327.0          4096.0    tm9w346e
# 34   7.568750e+09          652327.0          4096.0    50unngpx
# 35   7.568750e+09          652327.0          4096.0    b4nm365x
# 36   2.484270e+05          248427.0           100.0    hd5x19mf
# 37   1.332391e+06         1332391.0           128.0    ug7khnzy
# 38   5.024039e+06         5024039.0           256.0    nefxlbti
# 39   3.839953e+07        38399527.0           512.0    kiy5op73
# 40   1.948522e+07        19485223.0           512.0    k59ux1ud
# 41   2.213510e+05          221351.0            64.0    6mxwt5bv
# 42   3.713030e+05          371303.0            64.0    f3ova519
# 43   8.591082e+07        85910823.0           768.0    ysn4c19d
# 44   3.867833e+07        38678327.0             NaN    y2kr2dds
# 45   1.976402e+07        19764023.0             NaN    u9xmgd7q
# 46   8.632889e+07        86328887.0             NaN    rnch5pie
# 47   1.249224e+08          482615.0             NaN    qplmp4c7
# 48   1.249224e+08          482615.0             NaN    ehrwt506
# 49   1.249224e+08          482615.0           768.0    o5qvrgm9
# 50   7.748342e+08          804151.0             NaN    8l22br57
# 51   7.748342e+08          804151.0             NaN    mj708nev
# 52   7.748342e+08          804151.0             NaN    u0pc3awg
# 53   3.554666e+08          643383.0             NaN    1xig0nsq
# 54   3.554666e+08          643383.0             NaN    pbevzqfw
# 55   3.554666e+08          643383.0             NaN    anvutuie
# 56   3.892614e+07          321847.0             NaN    61ug0t74
# 57   3.892614e+07          321847.0             NaN    gzxeyy3i
# 58   3.892614e+07          321847.0             NaN    3ok9a5av
# 59   1.558616e+09         1005111.0             NaN    t5zvg8d2
# 60   1.558616e+09         1005111.0             NaN    sjdzwr68
# 61   1.558616e+09         1005111.0             NaN    u6xfw7cs
# 62   5.966933e+08          708919.0          1024.0    wv98xg4m
# 63   5.966933e+08          708919.0          1024.0    pmbp2b64
# 64   5.966933e+08          708919.0          1024.0    yv5o0gxc
# 65   1.721861e+09         1410359.0          2048.0    75yg2jkh
# 66   1.721861e+09         1410359.0          2048.0    izxcw360
# 67   1.721861e+09         1410359.0          2048.0    zlvmd9bw
# 68   4.024076e+09         1804087.0          2560.0    pdg49qhv
# 69   4.024076e+09         1804087.0          2560.0    xjq4jye9
# 70   4.024076e+09         1804087.0          2560.0    myfhftpf
# 71   1.402295e+06         1402295.0           128.0    kjzhj2hi
# 72   5.163575e+06         5163575.0           256.0    ziwi7inx
# 73   3.867833e+07        38678327.0           512.0    0shcg7vj
# 74   1.976402e+07        19764023.0           512.0    v23qyo3h
# 75   2.564390e+05          256439.0            64.0    k3rnaxp6
# 76   4.063910e+05          406391.0            64.0    ivtohdoe
# 77   8.632889e+07        86328887.0           768.0    jv76ygtg
# 78   1.338816e+06         1338816.0             NaN    w6s2kedf
# 79   5.036864e+06         5036864.0             NaN    ryejdbu6
# 80   3.842515e+07        38425152.0             NaN    agozhrdi
# 81   1.951085e+07        19510848.0             NaN    s8nzkh7e
# 82   2.245760e+05          224576.0             NaN    ha6cp7o9
# 83   3.745280e+05          374528.0             NaN    80bh1dfa
# 84   8.594925e+07        85949248.0             NaN    hkilj4nu
# 85   1.245428e+08          102976.0             NaN    86woqf96
# 86   1.245428e+08          102976.0             NaN    ipz8phs9
# 87   1.245428e+08          102976.0           768.0    toennk19
# 88   7.742017e+08          171584.0          1280.0    x70r3ay1
# 89   7.742017e+08          171584.0          1280.0    lgq149ob
# 90   7.742017e+08          171584.0             NaN    3rx88mm2
# 91   3.549604e+08          137280.0          1024.0    28jtx0bm
# 92   3.549604e+08          137280.0          1024.0    f0etu3e7
# 93   3.549604e+08          137280.0             NaN    6zoidf19
# 94   3.867296e+07           68672.0           512.0    l9m2jhtg
# 95   3.867296e+07           68672.0             NaN    ajttzt9u
# 96   3.867296e+07           68672.0             NaN    8hlbk8oi
# 97   1.557826e+09          214464.0             NaN    s3zuig1b
# 98   1.557826e+09          214464.0             NaN    qlls1xio
# 99   5.961872e+08          202816.0          1024.0    wwkd32m4
# 100  5.961872e+08          202816.0          1024.0    3y2w21l1
# 101  5.961872e+08          202816.0          1024.0    pybcr030
# 102  1.720849e+09          398400.0          2048.0    xml6lntm
# 103  1.720849e+09          398400.0          2048.0    cdo8hv8z
# 104  1.720849e+09          398400.0          2048.0    0htgmm95
# 105  4.022811e+09          539200.0          2560.0    b9d8q9n4
# 106  4.022811e+09          539200.0          2560.0    zx31au1u
# 107  4.022811e+09          539200.0          2560.0    kknm6n5z
# 108  1.338816e+06         1338816.0           128.0    y5lehk7p
# 109  5.036864e+06         5036864.0           256.0    a2n0rfgw
# 110  3.842515e+07        38425152.0           512.0    texklhu9
# 111  1.951085e+07        19510848.0           512.0    popq6vhk
# 112  2.245760e+05          224576.0            64.0    z72vr4yn
# 113  3.745280e+05          374528.0            64.0    qo2ivn61
# 114  8.594925e+07        85949248.0           768.0    t6gwpdj0
# 115  1.333419e+06         1333419.0             NaN    1flgx7vo
# 116  5.026091e+06         5026091.0             NaN    wx8ymlm2
# 117  3.840363e+07        38403627.0             NaN    i9bjldsw
# 118  1.948932e+07        19489323.0             NaN    2fd5dpas
# 119  2.218670e+05          221867.0             NaN    qlvs52jw
# 120  3.718190e+05          371819.0             NaN    bbgljnhz
# 121  8.591697e+07        85916971.0             NaN    76co2s7o
# 122  1.245105e+08           70699.0           768.0    1al8793r
# 123  1.245105e+08           70699.0           768.0    q9127opf
# 124  3.549174e+08           94251.0          1024.0    75u8htqu
# 125  3.549174e+08           94251.0          1024.0    yhoa0ujr
# 126  3.865144e+07           47147.0           512.0    suwh9qr7
# 127  3.865144e+07           47147.0           512.0    db3osyz8
# 128  5.961442e+08          159787.0          1024.0    xj8sjezv
# 129  5.961442e+08          159787.0          1024.0    48l2q5vc
# 130  3.840363e+07        38403627.0           512.0    7vcmor0f
# 131  8.591697e+07        85916971.0           768.0    29bcumvf
# 132  1.330592e+06         1330592.0             NaN    j6abinjx
# 133  5.020448e+06         5020448.0             NaN    1oxaglwr
# 134  3.839235e+07        38392352.0             NaN    8xzlnq4e
# 135  1.947805e+07        19478048.0             NaN    hwtjugzx
# 136  2.204480e+05          220448.0             NaN    mpz28dt2
# 137  3.704000e+05          370400.0             NaN    5gnt2y9i
# 138  8.590006e+07        85900064.0             NaN    plb0vehi
# 139  1.244936e+08           53792.0             NaN    uv8n3ztt
# 140  1.244936e+08           53792.0             NaN    mrjdid73
# 141  1.244936e+08           53792.0             NaN    p1muojki
# 142  7.741197e+08           89632.0             NaN    23ez4h0a
# 143  7.741197e+08           89632.0             NaN    gtzbc1cr
# 144  7.741197e+08           89632.0             NaN    sf2rqok1
# 145  3.548949e+08           71712.0             NaN    7umh5hzs
# 146  3.548949e+08           71712.0             NaN    gm5nmjfm
# 147  3.548949e+08           71712.0             NaN    v5af47rn
# 148  3.864016e+07           35872.0             NaN    xbtx91px
# 149  3.864016e+07           35872.0             NaN    h1zjigfh
# 150  3.864016e+07           35872.0           512.0    j2tbzi8q
# 151  1.557723e+09          112032.0             NaN    i1iqqjy6
# 152  1.557723e+09          112032.0             NaN    8uzizuje
# 153  1.557723e+09          112032.0             NaN    ojpl18v0
# 154  5.961216e+08          137248.0          1024.0    ngprbbp8
# 155  5.961216e+08          137248.0          1024.0    ywes38s0
# 156  5.961216e+08          137248.0          1024.0    qeesuu7j
# 157  1.720718e+09          267296.0          2048.0    qdfkd8f8
# 158  1.720718e+09          267296.0          2048.0    5w620vei
# 159  1.720718e+09          267296.0          2048.0    qjg0a8t1
# 160  4.022647e+09          375328.0          2560.0    rharwvsi
# 161  4.022647e+09          375328.0          2560.0    8p51n56l
# 162  4.022647e+09          375328.0          2560.0    qo6y6hey
# 163  7.568692e+09          594976.0          4096.0    0j1cip2u
# 164  7.568692e+09          594976.0          4096.0    jfhwp4t8
# 165  7.568692e+09          594976.0          4096.0    729fvoyp
# 166  1.327251e+06         1327251.0             NaN    63jczrjw
# 167  5.013779e+06         5013779.0             NaN    d2ckfjy7
# 168  3.837903e+07        38379027.0             NaN    ro89f7f7
# 169  1.946472e+07        19464723.0             NaN    bcqq6dhd
# 170  2.187710e+05          218771.0             NaN    vufrg1ip
# 171  3.687230e+05          368723.0             NaN    sw90mpik
# 172  8.588008e+07        85880083.0             NaN    sij80t1w
# 173  1.244736e+08           33811.0             NaN    ifawkwga
# 174  1.244736e+08           33811.0             NaN    hni6x9i8
# 175  1.244736e+08           33811.0           768.0    pms54eqm
# 176  7.740864e+08           56339.0             NaN    hb8x4lw0
# 177  7.740864e+08           56339.0             NaN    4nksp01n
# 178  7.740864e+08           56339.0             NaN    ecryes4t
# 179  3.548682e+08           45075.0             NaN    2nv5ivyg
# 180  3.548682e+08           45075.0             NaN    wl2a0blr
# 181  3.548682e+08           45075.0             NaN    ev3bi3w5
# 182  3.862684e+07           22547.0             NaN    1zkjexa2
# 183  3.862684e+07           22547.0             NaN    rgozvc6r
# 184  3.862684e+07           22547.0             NaN    kw41eo0q
# 185  1.557682e+09           70419.0             NaN    hr8foy2b
# 186  1.557682e+09           70419.0             NaN    gftonhuz
# 187  1.557682e+09           70419.0             NaN    2rcqmtu2
# 188  5.960950e+08          110611.0          1024.0    v71num98
# 189  5.960950e+08          110611.0          1024.0    2kcfiozw
# 190  5.960950e+08          110611.0          1024.0    omu4znpp
# 191  1.720665e+09          214035.0          2048.0    6q6d7w2v
# 192  1.720665e+09          214035.0          2048.0    4voyfea7
# 193  1.720665e+09          214035.0          2048.0    buz7yw8f
# 194  4.022581e+09          308755.0          2560.0    5nsz05qj
# 195  4.022581e+09          308755.0          2560.0    unkgbiww
# 196  4.022581e+09          308755.0          2560.0    vjhjl710
# 197  1.335989e+06         1335989.0             NaN    n1ksjyai
# 198  5.031221e+06         5031221.0             NaN    o9h0uz9n
# 199  3.841388e+07        38413877.0             NaN    acn730f9
# 200  1.949957e+07        19499573.0             NaN    r0owdoci
# 201  2.231570e+05          223157.0             NaN    o1w8mxzh
# 202  3.731090e+05          373109.0             NaN    bp9h7cfb
# 203  8.593234e+07        85932341.0             NaN    n0mh700g
# 204  1.245259e+08           86069.0           768.0    2h5otfl0
# 205  1.245259e+08           86069.0             NaN    z1akfkf7
# 206  1.245259e+08           86069.0             NaN    z704n1ig
# 207  7.741735e+08          143413.0             NaN    jq7dvdu4
# 208  7.741735e+08          143413.0             NaN    8kc3v7b7
# 209  7.741735e+08          143413.0             NaN    0frj1fa6
# 210  3.549379e+08          114741.0             NaN    xjsi94lj
# 211  3.549379e+08          114741.0             NaN    59mmpob8
# 212  3.549379e+08          114741.0             NaN    ue1dj29s
# 213  3.866168e+07           57397.0             NaN    qj2u3tvt
# 214  3.866168e+07           57397.0             NaN    sh3o7sxm
# 215  3.866168e+07           57397.0             NaN    xkthr7ip
# 216  1.557790e+09          179253.0             NaN    y4y28kf3
# 217  1.557790e+09          179253.0             NaN    ay8xlxlr
# 218  1.557790e+09          179253.0             NaN    m40epiut
# 219  5.961647e+08          180277.0          1024.0    5jcyyog3
# 220  5.961647e+08          180277.0          1024.0    1ma820zk
# 221  5.961647e+08          180277.0          1024.0    8hfqh3e4
# 222  1.720804e+09          353333.0          2048.0    dc3m3yrq
# 223  1.720804e+09          353333.0          2048.0    hv2qv5xh
# 224  1.720804e+09          353333.0          2048.0    keur9j0s
# 225  1.399097e+10          998453.0          5120.0    38g73rg7
# 226  1.399097e+10          998453.0          5120.0    314pthog
# 227  1.399097e+10          998453.0          5120.0    c88tr2ce
# 228  1.399097e+10          998453.0          5120.0    m02ncyl0
# 229  4.022755e+09          482869.0          2560.0    k08ojayh
# 230  4.022755e+09          482869.0          2560.0    j2xn3ahk
# 231  4.022755e+09          482869.0          2560.0    6f7aai8d
# 232  7.568864e+09          767029.0          4096.0    6zm55kcu
# 233  7.568864e+09          767029.0          4096.0    awj5zkjj
# 234  7.568864e+09          767029.0          4096.0    zkmmptow

# %%
import json
import pandas as pd

METRICS = {
    "best_test_final_next_activity_acc": "acc",
    "best_test_final_next_activity_f1": "f1",
}

GROUP_COLS = ["log", "backbone", "lr", "batch_size", "categorical_features", "continuous_features"]

EXTRA_COLS = ["project", "total_params", "trainable_params", "embedding_size"]
EXTRA_COLS = [c for c in EXTRA_COLS if c in runs.columns]

def make_hashable(x):
    """Convert unhashable objects (list/dict/set) into a stable string for grouping."""
    if pd.isna(x):
        return pd.NA
    if isinstance(x, (list, tuple)):
        return json.dumps(x, sort_keys=True)
    if isinstance(x, set):
        return json.dumps(sorted(list(x)))
    if isinstance(x, dict):
        return json.dumps(x, sort_keys=True)
    return x  # already hashable (str/int/float/etc.)

tmp = runs.copy()

# Ensure ALL grouping columns are hashable
for c in GROUP_COLS:
    if c in tmp.columns:
        tmp[c] = tmp[c].map(make_hashable)

# Build df
df = tmp[GROUP_COLS + ["id"] + list(METRICS.keys()) + EXTRA_COLS].copy()

# metrics numeric
for m in METRICS:
    df[m] = pd.to_numeric(df[m], errors="coerce")

# keep rows with at least one metric
df = df.dropna(subset=list(METRICS.keys()), how="all")

# Aggregate count + mean (KEEP NaN groups)
agg = (
    df.groupby(GROUP_COLS, dropna=False)
      .agg({m: ["count", "mean"] for m in METRICS})
)

# Flatten columns
agg.columns = [
    f"{METRICS[m]}_n_runs" if stat == "count" else f"{METRICS[m]}_mean"
    for (m, stat) in agg.columns
]

# Descriptors (KEEP NaN groups)
descriptors = (
    df.groupby(GROUP_COLS, dropna=False)[EXTRA_COLS].first()
    if EXTRA_COLS else None
)

# Best run id (choose priority metric)
BEST_METRIC = "best_test_final_next_activity_acc"
best_idx = df.groupby(GROUP_COLS, dropna=False)[BEST_METRIC].idxmax()
best_runs = df.loc[best_idx].set_index(GROUP_COLS)["id"].rename("best_run_id")

# Combine
summary = agg
if descriptors is not None:
    summary = summary.join(descriptors)
summary = summary.join(best_runs).reset_index()

# Display: show missing config as '-'
DISPLAY_COLS = GROUP_COLS + EXTRA_COLS
for c in DISPLAY_COLS:
    if c in summary.columns:
        summary[c] = summary[c].astype("object").where(summary[c].notna(), "-")

# Format means
for col in ["acc_mean", "f1_mean"]:
    if col in summary.columns:
        summary[col] = summary[col].map(lambda x: "-" if pd.isna(x) else f"{x:.4f}")

# Counts
for col in ["acc_n_runs", "f1_n_runs"]:
    if col in summary.columns:
        summary[col] = summary[col].fillna(0).astype(int)

summary = summary.sort_values(GROUP_COLS).reset_index(drop=True)

with pd.option_context("display.max_rows", None, "display.max_columns", None, "display.width", 200):
    display(summary)
# Out:
#                          log                       backbone       lr batch_size categorical_features   continuous_features  acc_n_runs acc_mean  f1_n_runs f1_mean                            project  \
# 0                      BPI12  baseline_transition_frequency        -          -                    -                     -           3   0.6165          2  0.3388                       baseline-nep
# 1                      BPI12                distill_128_6_2    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8381          5  0.6724        BPI12_lrz_distill_fixed_001
# 2                      BPI12                distill_256_6_4    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8373          5  0.6725        BPI12_lrz_distill_fixed_001
# 3                      BPI12               distill_512_12_8    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8412          5  0.6773        BPI12_lrz_distill_fixed_001
# 4                      BPI12                distill_512_6_8    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8308          5  0.6626        BPI12_lrz_distill_fixed_001
# 5                      BPI12                 distill_64_3_1    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8385          5  0.6752        BPI12_lrz_distill_fixed_001
# 6                      BPI12                 distill_64_6_1    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8396          5  0.6776        BPI12_lrz_distill_fixed_001
# 7                      BPI12              distill_768_12_12    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8306          5  0.6591        BPI12_lrz_distill_fixed_001
# 8                      BPI12                           gpt2  0.00005       64.0         ['activity']  ['accumulated_time']           8   0.7192          8  0.5343                      BPI12_lrz_001
# 9                      BPI12                           gpt2   0.0005       64.0         ['activity']  ['accumulated_time']           5   0.8020          5  0.6338                      BPI12_lrz_001
# 10                     BPI12                           gpt2    0.005       64.0         ['activity']  ['accumulated_time']          25   0.8182         25  0.6674                  BPI12_lrz_001_003
# 11                     BPI12                     gpt2-large  0.00005       64.0         ['activity']  ['accumulated_time']           6   0.7808          6  0.5978                      BPI12_lrz_001
# 12                     BPI12                     gpt2-large   0.0005       64.0         ['activity']  ['accumulated_time']           5   0.7796          5  0.6307                      BPI12_lrz_001
# 13                     BPI12                     gpt2-large    0.005       64.0         ['activity']  ['accumulated_time']           5   0.7989          5  0.6529                      BPI12_lrz_001
# 14                     BPI12                    gpt2-medium  0.00005       64.0         ['activity']  ['accumulated_time']           6   0.5249          6  0.4088                      BPI12_lrz_001
# 15                     BPI12                    gpt2-medium   0.0005       64.0         ['activity']  ['accumulated_time']           5   0.7457          5  0.6080                      BPI12_lrz_001
# 16                     BPI12                    gpt2-medium    0.005       64.0         ['activity']  ['accumulated_time']           5   0.7458          5  0.6233                      BPI12_lrz_001
# 17                     BPI12                      gpt2-mini  0.00005       64.0         ['activity']  ['accumulated_time']           8   0.7598          8  0.5841                      BPI12_lrz_001
# 18                     BPI12                      gpt2-mini   0.0005       64.0         ['activity']  ['accumulated_time']           5   0.8188          5  0.6643                      BPI12_lrz_001
# 19                     BPI12                      gpt2-mini    0.005       64.0         ['activity']  ['accumulated_time']           7   0.8158          7  0.6746                      BPI12_lrz_001
# 20                     BPI12                        gpt2-xl  0.00005       64.0         ['activity']  ['accumulated_time']           4   0.5706          4  0.3710                      BPI12_lrz_001
# 21                     BPI12                        gpt2-xl   0.0005       64.0         ['activity']  ['accumulated_time']           1   0.7645          1  0.6224                      BPI12_lrz_001
# 22                     BPI12                        gpt2-xl    0.005       64.0         ['activity']  ['accumulated_time']           4   0.8097          4  0.6675                      BPI12_lrz_001
# 23                     BPI12                     qwen3-0.6b  0.00005       64.0         ['activity']  ['accumulated_time']           5   0.7543          5  0.5909                BPI12_spark_002_002
# 24                     BPI12                     qwen3-0.6b   0.0005       64.0         ['activity']  ['accumulated_time']           5   0.7883          5  0.6236                BPI12_spark_002_002
# 25                     BPI12                     qwen3-0.6b    0.005       64.0         ['activity']  ['accumulated_time']           5   0.7547          5  0.6222                BPI12_spark_002_002
# 26                     BPI12                     qwen3-1.7b  0.00005       64.0         ['activity']  ['accumulated_time']           5   0.6195          5  0.4176                BPI12_spark_002_002
# 27                     BPI12                     qwen3-1.7b   0.0005       64.0         ['activity']  ['accumulated_time']           5   0.7381          5  0.5908                BPI12_spark_002_002
# 28                     BPI12                     qwen3-1.7b    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8207          5  0.6663                BPI12_spark_002_002
# 29                     BPI12                      qwen3-14b  0.00005       64.0         ['activity']  ['accumulated_time']           1   0.5977          1  0.4247                    BPI12_spark_002
# 30                     BPI12                      qwen3-14b    0.005       64.0         ['activity']  ['accumulated_time']           1   0.8261          1  0.6761                    BPI12_spark_002
# 31                     BPI12                       qwen3-4b  0.00005       64.0         ['activity']  ['accumulated_time']           5   0.7237          5  0.5392                BPI12_spark_002_002
# 32                     BPI12                       qwen3-4b   0.0005       64.0         ['activity']  ['accumulated_time']           5   0.7686          5  0.6056                BPI12_spark_002_002
# 33                     BPI12                       qwen3-4b    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8221          5  0.6663                BPI12_spark_002_002
# 34                     BPI12                       qwen3-8b  0.00005       32.0         ['activity']  ['accumulated_time']           1   0.7523          1  0.5806                    BPI12_spark_002
# 35                     BPI12                       qwen3-8b   0.0005       32.0         ['activity']  ['accumulated_time']           1   0.7785          1  0.6290                    BPI12_spark_002
# 36                     BPI12                       qwen3-8b    0.005       32.0         ['activity']  ['accumulated_time']           1   0.8292          1  0.6670                    BPI12_spark_002
# 37                     BPI12                            rnn   0.0001       64.0         ['activity']  ['accumulated_time']          10   0.6798         10  0.5226     lstm_bpi12_size100_layers3_001
# 38                     BPI12                scratch_128_6_2   0.0001       64.0         ['activity']  ['accumulated_time']           5   0.8432          5  0.6890  BPI12_lrz_nanogpt_scratch_new_001
# 39                     BPI12                scratch_256_6_4   0.0001       64.0         ['activity']  ['accumulated_time']           5   0.8432          5  0.6961  BPI12_lrz_nanogpt_scratch_new_001
# 40                     BPI12               scratch_512_12_8   0.0001       64.0         ['activity']  ['accumulated_time']           5   0.8420          5  0.6962  BPI12_lrz_nanogpt_scratch_new_001
# 41                     BPI12                scratch_512_6_8   0.0001       64.0         ['activity']  ['accumulated_time']           5   0.8439          5  0.6907  BPI12_lrz_nanogpt_scratch_new_001
# 42                     BPI12                 scratch_64_3_1   0.0001       64.0         ['activity']  ['accumulated_time']           5   0.8397          5  0.6813  BPI12_lrz_nanogpt_scratch_new_001
# 43                     BPI12                 scratch_64_6_1   0.0001       64.0         ['activity']  ['accumulated_time']           5   0.8418          5  0.6814  BPI12_lrz_nanogpt_scratch_new_001
# 44                     BPI12              scratch_768_12_12   0.0001       64.0         ['activity']  ['accumulated_time']           5   0.8423          5  0.6978  BPI12_lrz_nanogpt_scratch_new_001
# 45                     BPI15  baseline_transition_frequency        -          -                    -                     -           2   0.1007          1  0.0659                       baseline-nep
# 46                     BPI15               distill_512_12_8    0.005       64.0         ['activity']  ['accumulated_time']           5   0.0788          5  0.0216        BPI15_lrz_distill_fixed_001
# 47                     BPI15                distill_512_6_8    0.005       64.0         ['activity']  ['accumulated_time']           1   0.0375          1  0.0010        BPI15_lrz_distill_fixed_001
# 48                     BPI15              distill_768_12_12    0.005       64.0         ['activity']  ['accumulated_time']           4   0.0555          4  0.0092        BPI15_lrz_distill_fixed_001
# 49                     BPI15                           gpt2  0.00005       64.0         ['activity']  ['accumulated_time']           5   0.0827          5  0.0139                      BPI15_lrz_001
# 50                     BPI15                           gpt2   0.0005       64.0         ['activity']  ['accumulated_time']           5   0.1823          5  0.0913                      BPI15_lrz_001
# 51                     BPI15                           gpt2    0.005       64.0         ['activity']  ['accumulated_time']          15   0.2153         15  0.1102                  BPI15_lrz_002_001
# 52                     BPI15                     gpt2-large  0.00005       64.0         ['activity']  ['accumulated_time']           5   0.0544          5  0.0084                      BPI15_lrz_001
# 53                     BPI15                     gpt2-large   0.0005       64.0         ['activity']  ['accumulated_time']           5   0.1419          5  0.0649                      BPI15_lrz_001
# 54                     BPI15                     gpt2-large    0.005       64.0         ['activity']  ['accumulated_time']           5   0.2105          5  0.1038                      BPI15_lrz_001
# 55                     BPI15                    gpt2-medium  0.00005       64.0         ['activity']  ['accumulated_time']           5   0.0433          5  0.0028                      BPI15_lrz_001
# 56                     BPI15                    gpt2-medium   0.0005       64.0         ['activity']  ['accumulated_time']           5   0.0412          5  0.0023                      BPI15_lrz_001
# 57                     BPI15                    gpt2-medium    0.005       64.0         ['activity']  ['accumulated_time']           5   0.2047          5  0.1039                      BPI15_lrz_001
# 58                     BPI15                      gpt2-mini  0.00005       64.0         ['activity']  ['accumulated_time']           5   0.0918          5  0.0278                      BPI15_lrz_001
# 59                     BPI15                      gpt2-mini   0.0005       64.0         ['activity']  ['accumulated_time']           5   0.2001          5  0.1000                      BPI15_lrz_001
# 60                     BPI15                      gpt2-mini    0.005       64.0         ['activity']  ['accumulated_time']           5   0.2186          5  0.1098                      BPI15_lrz_001
# 61                     BPI15                        gpt2-xl  0.00005       64.0         ['activity']  ['accumulated_time']           4   0.0561          4  0.0062                      BPI15_lrz_001
# 62                     BPI15                        gpt2-xl   0.0005       64.0         ['activity']  ['accumulated_time']           4   0.1169          4  0.0461                      BPI15_lrz_001
# 63                     BPI15                        gpt2-xl    0.005       64.0         ['activity']  ['accumulated_time']           4   0.2054          4  0.0998                      BPI15_lrz_001
# 64                     BPI15                     qwen3-0.6b  0.00005       64.0         ['activity']  ['accumulated_time']           5   0.1441          5  0.0639                      BPI15_lrz_002
# 65                     BPI15                     qwen3-0.6b   0.0005       64.0         ['activity']  ['accumulated_time']           5   0.1788          5  0.0835                      BPI15_lrz_002
# 66                     BPI15                     qwen3-0.6b    0.005       64.0         ['activity']  ['accumulated_time']           5   0.1917          5  0.0862                      BPI15_lrz_002
# 67                     BPI15                     qwen3-1.7b  0.00005       64.0         ['activity']  ['accumulated_time']           5   0.0735          5  0.0128                      BPI15_lrz_002
# 68                     BPI15                     qwen3-1.7b   0.0005       64.0         ['activity']  ['accumulated_time']           5   0.0825          5  0.0264                      BPI15_lrz_002
# 69                     BPI15                     qwen3-1.7b    0.005       64.0         ['activity']  ['accumulated_time']           5   0.1797          5  0.0840                      BPI15_lrz_002
# 70                     BPI15                       qwen3-4b  0.00005       64.0         ['activity']  ['accumulated_time']           4   0.0662          4  0.0109                      BPI15_lrz_002
# 71                     BPI15                       qwen3-4b   0.0005       64.0         ['activity']  ['accumulated_time']           5   0.1436          5  0.0599                      BPI15_lrz_002
# 72                     BPI15                       qwen3-4b    0.005       64.0         ['activity']  ['accumulated_time']           5   0.1964          5  0.0899                      BPI15_lrz_002
# 73                     BPI15                scratch_128_6_2   0.0001       64.0         ['activity']  ['accumulated_time']           5   0.2332          5  0.0976  BPI15_lrz_nanogpt_scratch_new_001
# 74                     BPI15                scratch_256_6_4   0.0001       64.0         ['activity']  ['accumulated_time']           5   0.2405          5  0.1053  BPI15_lrz_nanogpt_scratch_new_001
# 75                     BPI15               scratch_512_12_8   0.0001       64.0         ['activity']  ['accumulated_time']           5   0.2455          5  0.1019  BPI15_lrz_nanogpt_scratch_new_001
# 76                     BPI15                scratch_512_6_8   0.0001       64.0         ['activity']  ['accumulated_time']           5   0.2426          5  0.1037  BPI15_lrz_nanogpt_scratch_new_001
# 77                     BPI15                 scratch_64_3_1   0.0001       64.0         ['activity']  ['accumulated_time']           5   0.1888          5  0.0751  BPI15_lrz_nanogpt_scratch_new_001
# 78                     BPI15                 scratch_64_6_1   0.0001       64.0         ['activity']  ['accumulated_time']           5   0.1954          5  0.0763  BPI15_lrz_nanogpt_scratch_new_001
# 79                     BPI15              scratch_768_12_12   0.0001       64.0         ['activity']  ['accumulated_time']           5   0.2292          5  0.0892  BPI15_lrz_nanogpt_scratch_new_001
# 80                     BPI17  baseline_transition_frequency        -          -                    -                     -           2   0.6883          1  0.4607                       baseline-nep
# 81                     BPI17                distill_128_6_2    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8283          5  0.6610        BPI17_lrz_distill_fixed_001
# 82                     BPI17                distill_256_6_4    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8304          5  0.6607        BPI17_lrz_distill_fixed_001
# 83                     BPI17               distill_512_12_8    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8275          5  0.6606        BPI17_lrz_distill_fixed_001
# 84                     BPI17                distill_512_6_8    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8274          5  0.6596        BPI17_lrz_distill_fixed_001
# 85                     BPI17                 distill_64_3_1    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8286          5  0.6598        BPI17_lrz_distill_fixed_001
# 86                     BPI17                 distill_64_6_1    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8269          5  0.6593        BPI17_lrz_distill_fixed_001
# 87                     BPI17              distill_768_12_12    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8277          5  0.6653        BPI17_lrz_distill_fixed_001
# 88                     BPI17                           gpt2  0.00005       64.0         ['activity']  ['accumulated_time']           5   0.8040          5  0.6199                      BPI17_lrz_001
# 89                     BPI17                           gpt2   0.0005       64.0         ['activity']  ['accumulated_time']           5   0.8136          5  0.6427                      BPI17_lrz_001
# 90                     BPI17                           gpt2    0.005       64.0         ['activity']  ['accumulated_time']          20   0.8187         20  0.6567                  BPI17_lrz_002_002
# 91                     BPI17                     gpt2-large  0.00005       64.0         ['activity']  ['accumulated_time']           5   0.8075          5  0.6357                BPI17_spark_002_001
# 92                     BPI17                     gpt2-large   0.0005       64.0         ['activity']  ['accumulated_time']           5   0.8161          5  0.6528                BPI17_spark_002_001
# 93                     BPI17                     gpt2-large    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8150          5  0.6578                      BPI17_lrz_001
# 94                     BPI17                    gpt2-medium  0.00005       64.0         ['activity']  ['accumulated_time']           5   0.7434          5  0.5969                BPI17_spark_002_001
# 95                     BPI17                    gpt2-medium   0.0005       64.0         ['activity']  ['accumulated_time']           5   0.7825          5  0.6234                BPI17_spark_002_001
# 96                     BPI17                    gpt2-medium    0.005       64.0         ['activity']  ['accumulated_time']           5   0.7708          5  0.6279                      BPI17_lrz_001
# 97                     BPI17                      gpt2-mini  0.00005       64.0         ['activity']  ['accumulated_time']           5   0.7845          5  0.5982                BPI17_spark_002_001
# 98                     BPI17                      gpt2-mini   0.0005       64.0         ['activity']  ['accumulated_time']           5   0.8033          5  0.6314                      BPI17_lrz_001
# 99                     BPI17                      gpt2-mini    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8162          5  0.6627                      BPI17_lrz_001
# 100                    BPI17                        gpt2-xl   0.0005       64.0         ['activity']  ['accumulated_time']           1   0.7999          1  0.6224                      BPI17_lrz_001
# 101                    BPI17                        gpt2-xl    0.005       64.0         ['activity']  ['accumulated_time']           1   0.8036          1  0.6452                      BPI17_lrz_001
# 102                    BPI17                     qwen3-0.6b  0.00005       64.0         ['activity']  ['accumulated_time']           5   0.8030          5  0.6254                      BPI17_lrz_002
# 103                    BPI17                     qwen3-0.6b   0.0005       64.0         ['activity']  ['accumulated_time']           5   0.8086          5  0.6523                BPI17_spark_002_001
# 104                    BPI17                     qwen3-0.6b    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8175          5  0.6562                BPI17_spark_002_001
# 105                    BPI17                     qwen3-1.7b  0.00005       64.0         ['activity']  ['accumulated_time']           5   0.7772          5  0.5909                BPI17_spark_002_001
# 106                    BPI17                     qwen3-1.7b   0.0005       64.0         ['activity']  ['accumulated_time']           5   0.7881          5  0.6116                BPI17_spark_002_001
# 107                    BPI17                     qwen3-1.7b    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8228          5  0.6663                BPI17_spark_002_001
# 108                    BPI17                       qwen3-4b  0.00005       64.0         ['activity']  ['accumulated_time']           1   0.7923          1  0.6083                BPI17_spark_002_002
# 109                    BPI17                       qwen3-4b   0.0005       64.0         ['activity']  ['accumulated_time']           1   0.8154          1  0.6703                BPI17_spark_002_002
# 110                    BPI17                       qwen3-4b    0.005       64.0         ['activity']  ['accumulated_time']           1   0.8225          1  0.6771                BPI17_spark_002_002
# 111                    BPI17                scratch_128_6_2   0.0001       64.0         ['activity']  ['accumulated_time']           5   0.8367          5  0.6724  BPI17_lrz_nanogpt_scratch_new_001
# 112                    BPI17                scratch_256_6_4   0.0001       64.0         ['activity']  ['accumulated_time']           5   0.8363          5  0.6782  BPI17_lrz_nanogpt_scratch_new_001
# 113                    BPI17               scratch_512_12_8   0.0001       64.0         ['activity']  ['accumulated_time']           5   0.8368          5  0.6859  BPI17_lrz_nanogpt_scratch_new_001
# 114                    BPI17                scratch_512_6_8   0.0001       64.0         ['activity']  ['accumulated_time']           5   0.8366          5  0.6776  BPI17_lrz_nanogpt_scratch_new_001
# 115                    BPI17                 scratch_64_3_1   0.0001       64.0         ['activity']  ['accumulated_time']           5   0.8325          5  0.6579  BPI17_lrz_nanogpt_scratch_new_001
# 116                    BPI17                 scratch_64_6_1   0.0001       64.0         ['activity']  ['accumulated_time']           5   0.8351          5  0.6600  BPI17_lrz_nanogpt_scratch_new_001
# 117                    BPI17              scratch_768_12_12   0.0001       64.0         ['activity']  ['accumulated_time']           5   0.8344          5  0.6781  BPI17_lrz_nanogpt_scratch_new_001
# 118                    BPI19  baseline_transition_frequency        -          -                    -                     -           2   0.6815          1  0.1537                       baseline-nep
# 119                    BPI19                distill_128_6_2    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8324          5  0.2063        BPI19_lrz_distill_fixed_001
# 120                    BPI19                distill_256_6_4    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8366          5  0.2209        BPI19_lrz_distill_fixed_001
# 121                    BPI19               distill_512_12_8    0.005       64.0         ['activity']  ['accumulated_time']           3   0.8264          3  0.1882        BPI19_lrz_distill_fixed_001
# 122                    BPI19                distill_512_6_8    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8309          5  0.2029        BPI19_lrz_distill_fixed_001
# 123                    BPI19                 distill_64_3_1    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8317          5  0.2024        BPI19_lrz_distill_fixed_001
# 124                    BPI19                 distill_64_6_1    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8351          5  0.2018        BPI19_lrz_distill_fixed_001
# 125                    BPI19              distill_768_12_12    0.005       64.0         ['activity']  ['accumulated_time']           3   0.8319          3  0.2047        BPI19_lrz_distill_fixed_001
# 126                    BPI19                           gpt2  0.00005       64.0         ['activity']  ['accumulated_time']          12   0.7867         12  0.1511                  BPI19_lrz_002_002
# 127                    BPI19                           gpt2   0.0005       64.0         ['activity']  ['accumulated_time']           1   0.6828          1  0.1876                  BPI19_lrz_002_002
# 128                    BPI19                    gpt2-medium  0.00005       32.0         ['activity']  ['accumulated_time']           1   0.7454          1  0.1081                  BPI19_lrz_002_002
# 129                    BPI19                    gpt2-medium  0.00005       64.0         ['activity']  ['accumulated_time']           1   0.5769          1  0.0943                      BPI19_lrz_001
# 130                    BPI19                      gpt2-mini  0.00005       64.0         ['activity']  ['accumulated_time']          13   0.7893         13  0.1633                  BPI19_lrz_002_002
# 131                    BPI19                      gpt2-mini   0.0005       64.0         ['activity']  ['accumulated_time']           1   0.6762          1  0.2409                  BPI19_lrz_002_002
# 132                    BPI19                     qwen3-0.6b  0.00005       64.0         ['activity']  ['accumulated_time']           3   0.7350          3  0.1771                      BPI19_lrz_002
# 133                    BPI19                     qwen3-0.6b   0.0005       64.0         ['activity']  ['accumulated_time']           1   0.6729          1  0.2357                      BPI19_lrz_002
# 134                    BPI19               scratch_512_12_8   0.0001       64.0         ['activity']  ['accumulated_time']           4   0.8458          4  0.2923  BPI19_lrz_nanogpt_scratch_new_001
# 135                    BPI19              scratch_768_12_12   0.0001       64.0         ['activity']  ['accumulated_time']           5   0.8429          5  0.2871  BPI19_lrz_nanogpt_scratch_new_001
# 136  BPI20PrepaidTravelCosts  baseline_transition_frequency        -          -                    -                     -           2   0.8329          1  0.5075                       baseline-nep
# 137  BPI20PrepaidTravelCosts                distill_128_6_2    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8927          5  0.5577     BPI20PTC_lrz_distill_fixed_001
# 138  BPI20PrepaidTravelCosts                distill_256_6_4    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8640          5  0.4804     BPI20PTC_lrz_distill_fixed_001
# 139  BPI20PrepaidTravelCosts               distill_512_12_8    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8473          5  0.4723     BPI20PTC_lrz_distill_fixed_001
# 140  BPI20PrepaidTravelCosts                distill_512_6_8    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8619          5  0.4608     BPI20PTC_lrz_distill_fixed_001
# 141  BPI20PrepaidTravelCosts                 distill_64_3_1    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8943          5  0.5713     BPI20PTC_lrz_distill_fixed_001
# 142  BPI20PrepaidTravelCosts                 distill_64_6_1    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8969          5  0.5759     BPI20PTC_lrz_distill_fixed_001
# 143  BPI20PrepaidTravelCosts              distill_768_12_12    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8381          5  0.4185     BPI20PTC_lrz_distill_fixed_001
# 144  BPI20PrepaidTravelCosts                           gpt2  0.00005       64.0         ['activity']  ['accumulated_time']           5   0.8278          5  0.4155                  BPI20_PTC_lrz_001
# 145  BPI20PrepaidTravelCosts                           gpt2   0.0005       64.0         ['activity']  ['accumulated_time']           5   0.8497          5  0.5342                  BPI20_PTC_lrz_001
# 146  BPI20PrepaidTravelCosts                           gpt2    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8415          5  0.5276                  BPI20_PTC_lrz_001
# 147  BPI20PrepaidTravelCosts                     gpt2-large  0.00005       64.0         ['activity']  ['accumulated_time']           5   0.5073          5  0.2086                  BPI20_PTC_lrz_001
# 148  BPI20PrepaidTravelCosts                     gpt2-large   0.0005       64.0         ['activity']  ['accumulated_time']           5   0.8433          5  0.5221                  BPI20_PTC_lrz_001
# 149  BPI20PrepaidTravelCosts                     gpt2-large    0.005       64.0         ['activity']  ['accumulated_time']           4   0.8430          4  0.5224                  BPI20_PTC_lrz_001
# 150  BPI20PrepaidTravelCosts                    gpt2-medium  0.00005       64.0         ['activity']  ['accumulated_time']           5   0.5041          5  0.2086                  BPI20_PTC_lrz_001
# 151  BPI20PrepaidTravelCosts                    gpt2-medium   0.0005       64.0         ['activity']  ['accumulated_time']           5   0.8100          5  0.5047                  BPI20_PTC_lrz_001
# 152  BPI20PrepaidTravelCosts                    gpt2-medium    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8250          5  0.5045                  BPI20_PTC_lrz_001
# 153  BPI20PrepaidTravelCosts                      gpt2-mini  0.00005       64.0         ['activity']  ['accumulated_time']           5   0.7999          5  0.4525                  BPI20_PTC_lrz_001
# 154  BPI20PrepaidTravelCosts                      gpt2-mini   0.0005       64.0         ['activity']  ['accumulated_time']           5   0.8499          5  0.5401                  BPI20_PTC_lrz_001
# 155  BPI20PrepaidTravelCosts                      gpt2-mini    0.005       64.0         ['activity']  ['accumulated_time']          15   0.8594         15  0.5510                  BPI20_lrz_002_002
# 156  BPI20PrepaidTravelCosts                        gpt2-xl  0.00005       64.0         ['activity']  ['accumulated_time']           4   0.6898          4  0.3124                  BPI20_PTC_lrz_001
# 157  BPI20PrepaidTravelCosts                        gpt2-xl   0.0005       64.0         ['activity']  ['accumulated_time']           4   0.8543          4  0.5352                  BPI20_PTC_lrz_001
# 158  BPI20PrepaidTravelCosts                        gpt2-xl    0.005       64.0         ['activity']  ['accumulated_time']           4   0.8472          4  0.5255                  BPI20_PTC_lrz_001
# 159  BPI20PrepaidTravelCosts                     qwen3-0.6b  0.00005       64.0         ['activity']  ['accumulated_time']          11   0.7760         11  0.4521                  BPI20_PTC_lrz_002
# 160  BPI20PrepaidTravelCosts                     qwen3-0.6b   0.0005       64.0         ['activity']  ['accumulated_time']          10   0.8478         10  0.5254                  BPI20_PTC_lrz_002
# 161  BPI20PrepaidTravelCosts                     qwen3-0.6b    0.005       64.0         ['activity']  ['accumulated_time']          10   0.8506         10  0.5378                  BPI20_PTC_lrz_002
# 162  BPI20PrepaidTravelCosts                     qwen3-1.7b  0.00005       64.0         ['activity']  ['accumulated_time']          10   0.7442         10  0.3958                  BPI20_PTC_lrz_002
# 163  BPI20PrepaidTravelCosts                     qwen3-1.7b   0.0005       64.0         ['activity']  ['accumulated_time']          10   0.7995         10  0.4778                  BPI20_PTC_lrz_002
# 164  BPI20PrepaidTravelCosts                     qwen3-1.7b    0.005       64.0         ['activity']  ['accumulated_time']          10   0.8478         10  0.5320                  BPI20_PTC_lrz_002
# 165  BPI20PrepaidTravelCosts                       qwen3-4b  0.00005       64.0         ['activity']  ['accumulated_time']          10   0.7929         10  0.4515                  BPI20_PTC_lrz_002
# 166  BPI20PrepaidTravelCosts                       qwen3-4b   0.0005       64.0         ['activity']  ['accumulated_time']          10   0.8313         10  0.5063                  BPI20_PTC_lrz_002
# 167  BPI20PrepaidTravelCosts                       qwen3-4b    0.005       64.0         ['activity']  ['accumulated_time']          10   0.8542         10  0.5298                  BPI20_PTC_lrz_002
# 168  BPI20PrepaidTravelCosts                       qwen3-8b  0.00005       32.0         ['activity']  ['accumulated_time']           5   0.7642          5  0.4304                BPI20_PTC_spark_001
# 169  BPI20PrepaidTravelCosts                       qwen3-8b   0.0005       32.0         ['activity']  ['accumulated_time']           5   0.8146          5  0.4370                BPI20_PTC_spark_001
# 170  BPI20PrepaidTravelCosts                       qwen3-8b    0.005       32.0         ['activity']  ['accumulated_time']           5   0.8475          5  0.5158                BPI20_PTC_spark_001
# 171   BPI20RequestForPayment  baseline_transition_frequency        -          -                    -                     -           2   0.8958          1  0.4905                       baseline-nep
# 172   BPI20RequestForPayment                distill_128_6_2    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8984          5  0.4666     BPI20RFP_lrz_distill_fixed_001
# 173   BPI20RequestForPayment                distill_256_6_4    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8973          5  0.4679     BPI20RFP_lrz_distill_fixed_001
# 174   BPI20RequestForPayment               distill_512_12_8    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8970          5  0.4704     BPI20RFP_lrz_distill_fixed_001
# 175   BPI20RequestForPayment                distill_512_6_8    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8969          5  0.4654     BPI20RFP_lrz_distill_fixed_001
# 176   BPI20RequestForPayment                 distill_64_3_1    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8993          5  0.5010     BPI20RFP_lrz_distill_fixed_001
# 177   BPI20RequestForPayment                 distill_64_6_1    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8991          5  0.4821     BPI20RFP_lrz_distill_fixed_001
# 178   BPI20RequestForPayment              distill_768_12_12    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8967          5  0.4636     BPI20RFP_lrz_distill_fixed_001
# 179   BPI20RequestForPayment                           gpt2  0.00005       64.0         ['activity']  ['accumulated_time']           5   0.8948          5  0.4234                  BPI20_RFP_lrz_001
# 180   BPI20RequestForPayment                           gpt2   0.0005       64.0         ['activity']  ['accumulated_time']           5   0.8984          5  0.5066                  BPI20_RFP_lrz_001
# 181   BPI20RequestForPayment                           gpt2    0.005       64.0         ['activity']  ['accumulated_time']          20   0.8966         20  0.4970                  BPI20_lrz_002_002
# 182   BPI20RequestForPayment                     gpt2-large  0.00005       64.0         ['activity']  ['accumulated_time']           5   0.8933          5  0.4310                  BPI20_RFP_lrz_001
# 183   BPI20RequestForPayment                     gpt2-large   0.0005       64.0         ['activity']  ['accumulated_time']           5   0.8908          5  0.4927                  BPI20_RFP_lrz_001
# 184   BPI20RequestForPayment                     gpt2-large    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8866          5  0.5168                  BPI20_RFP_lrz_001
# 185   BPI20RequestForPayment                    gpt2-medium  0.00005       64.0         ['activity']  ['accumulated_time']           5   0.5990          5  0.2584                  BPI20_RFP_lrz_001
# 186   BPI20RequestForPayment                    gpt2-medium   0.0005       64.0         ['activity']  ['accumulated_time']           5   0.8450          5  0.4336                  BPI20_RFP_lrz_001
# 187   BPI20RequestForPayment                    gpt2-medium    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8860          5  0.4959                  BPI20_RFP_lrz_001
# 188   BPI20RequestForPayment                      gpt2-mini  0.00005       64.0         ['activity']  ['accumulated_time']           5   0.8944          5  0.4966                  BPI20_RFP_lrz_001
# 189   BPI20RequestForPayment                      gpt2-mini   0.0005       64.0         ['activity']  ['accumulated_time']           5   0.8985          5  0.5046                  BPI20_RFP_lrz_001
# 190   BPI20RequestForPayment                      gpt2-mini    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8944          5  0.5096                  BPI20_RFP_lrz_001
# 191   BPI20RequestForPayment                        gpt2-xl  0.00005       64.0         ['activity']  ['accumulated_time']           4   0.8936          4  0.4447                  BPI20_RFP_lrz_001
# 192   BPI20RequestForPayment                        gpt2-xl   0.0005       64.0         ['activity']  ['accumulated_time']           4   0.8859          4  0.4893                  BPI20_RFP_lrz_001
# 193   BPI20RequestForPayment                        gpt2-xl    0.005       64.0         ['activity']  ['accumulated_time']           4   0.8820          4  0.5093                  BPI20_RFP_lrz_001
# 194   BPI20RequestForPayment                     qwen3-0.6b  0.00005       64.0         ['activity']  ['accumulated_time']           5   0.8872          5  0.4966                  BPI20_RFP_lrz_002
# 195   BPI20RequestForPayment                     qwen3-0.6b   0.0005       64.0         ['activity']  ['accumulated_time']           5   0.8990          5  0.5156                  BPI20_RFP_lrz_002
# 196   BPI20RequestForPayment                     qwen3-0.6b    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8965          5  0.5114                  BPI20_RFP_lrz_002
# 197   BPI20RequestForPayment                     qwen3-1.7b  0.00005       64.0         ['activity']  ['accumulated_time']           5   0.8741          5  0.4205                  BPI20_RFP_lrz_002
# 198   BPI20RequestForPayment                     qwen3-1.7b   0.0005       64.0         ['activity']  ['accumulated_time']           5   0.8866          5  0.4874                  BPI20_RFP_lrz_002
# 199   BPI20RequestForPayment                     qwen3-1.7b    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8889          5  0.5123                  BPI20_RFP_lrz_002
# 200   BPI20RequestForPayment                       qwen3-4b  0.00005       64.0         ['activity']  ['accumulated_time']           5   0.8763          5  0.4653                  BPI20_RFP_lrz_002
# 201   BPI20RequestForPayment                       qwen3-4b   0.0005       64.0         ['activity']  ['accumulated_time']           4   0.8867          4  0.4813                  BPI20_RFP_lrz_002
# 202   BPI20RequestForPayment                       qwen3-4b    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8935          5  0.4993                  BPI20_RFP_lrz_002
# 203    BPI20TravelPermitData  baseline_transition_frequency        -          -                    -                     -           2   0.7681          1  0.3780                       baseline-nep
# 204    BPI20TravelPermitData                distill_128_6_2    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8409          5  0.4793     BPI20TPD_lrz_distill_fixed_001
# 205    BPI20TravelPermitData                distill_256_6_4    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8292          5  0.4674     BPI20TPD_lrz_distill_fixed_001
# 206    BPI20TravelPermitData               distill_512_12_8    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8403          5  0.4787     BPI20TPD_lrz_distill_fixed_001
# 207    BPI20TravelPermitData                distill_512_6_8    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8365          5  0.4813     BPI20TPD_lrz_distill_fixed_001
# 208    BPI20TravelPermitData                 distill_64_3_1    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8369          5  0.4742     BPI20TPD_lrz_distill_fixed_001
# 209    BPI20TravelPermitData                 distill_64_6_1    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8348          5  0.4720     BPI20TPD_lrz_distill_fixed_001
# 210    BPI20TravelPermitData              distill_768_12_12    0.005       64.0         ['activity']  ['accumulated_time']           5   0.8072          5  0.4279     BPI20TPD_lrz_distill_fixed_001
# 211    BPI20TravelPermitData                           gpt2  0.00005       64.0         ['activity']  ['accumulated_time']          10   0.7568         10  0.3695                  BPI20_lrz_002_002
# 212    BPI20TravelPermitData                           gpt2   0.0005       64.0         ['activity']  ['accumulated_time']           5   0.7511          5  0.3688                  BPI20_TPD_lrz_001
# 213    BPI20TravelPermitData                           gpt2    0.005       64.0         ['activity']  ['accumulated_time']           5   0.7641          5  0.3778                  BPI20_TPD_lrz_001
# 214    BPI20TravelPermitData                     gpt2-large  0.00005       64.0         ['activity']  ['accumulated_time']           5   0.7355          5  0.3396                  BPI20_TPD_lrz_001
# 215    BPI20TravelPermitData                     gpt2-large   0.0005       64.0         ['activity']  ['accumulated_time']           5   0.7427          5  0.3706                  BPI20_TPD_lrz_001
# 216    BPI20TravelPermitData                     gpt2-large    0.005       64.0         ['activity']  ['accumulated_time']           5   0.7285          5  0.3648                  BPI20_TPD_lrz_001
# 217    BPI20TravelPermitData                    gpt2-medium  0.00005       64.0         ['activity']  ['accumulated_time']           5   0.5269          5  0.2433                  BPI20_TPD_lrz_001
# 218    BPI20TravelPermitData                    gpt2-medium   0.0005       64.0         ['activity']  ['accumulated_time']           5   0.6890          5  0.3796                  BPI20_TPD_lrz_001
# 219    BPI20TravelPermitData                    gpt2-medium    0.005       64.0         ['activity']  ['accumulated_time']           5   0.6898          5  0.3790                  BPI20_TPD_lrz_001
# 220    BPI20TravelPermitData                      gpt2-mini  0.00005       64.0         ['activity']  ['accumulated_time']           5   0.7568          5  0.3765                  BPI20_TPD_lrz_001
# 221    BPI20TravelPermitData                      gpt2-mini   0.0005       64.0         ['activity']  ['accumulated_time']           5   0.7624          5  0.3872                  BPI20_TPD_lrz_001
# 222    BPI20TravelPermitData                      gpt2-mini    0.005       64.0         ['activity']  ['accumulated_time']           5   0.7586          5  0.4075                  BPI20_TPD_lrz_001
# 223    BPI20TravelPermitData                        gpt2-xl  0.00005       64.0         ['activity']  ['accumulated_time']           4   0.7255          4  0.3605                  BPI20_TPD_lrz_001
# 224    BPI20TravelPermitData                        gpt2-xl   0.0005       64.0         ['activity']  ['accumulated_time']           4   0.6817          4  0.3327                  BPI20_TPD_lrz_001
# 225    BPI20TravelPermitData                        gpt2-xl    0.005       64.0         ['activity']  ['accumulated_time']           4   0.6984          4  0.3754                  BPI20_TPD_lrz_001
# 226    BPI20TravelPermitData                     qwen3-0.6b  0.00005       64.0         ['activity']  ['accumulated_time']           5   0.7390          5  0.3741                BPI20_TPD_spark_001
# 227    BPI20TravelPermitData                     qwen3-0.6b   0.0005       64.0         ['activity']  ['accumulated_time']           5   0.7255          5  0.3559                BPI20_TPD_spark_001
# 228    BPI20TravelPermitData                     qwen3-0.6b    0.005       64.0         ['activity']  ['accumulated_time']           2   0.7262          2  0.3781                BPI20_TPD_spark_001
# 229    BPI20TravelPermitData                     qwen3-1.7b  0.00005       64.0         ['activity']  ['accumulated_time']           5   0.6254          5  0.2992                BPI20_TPD_spark_001
# 230    BPI20TravelPermitData                     qwen3-1.7b   0.0005       64.0         ['activity']  ['accumulated_time']           5   0.6849          5  0.3385                BPI20_TPD_spark_001
# 231    BPI20TravelPermitData                     qwen3-1.7b    0.005       64.0         ['activity']  ['accumulated_time']           2   0.7551          2  0.4121                BPI20_TPD_spark_001
# 232    BPI20TravelPermitData                      qwen3-14b  0.00005       16.0         ['activity']  ['accumulated_time']           2   0.4136          2  0.1356                BPI20_TPD_spark_001
# 233    BPI20TravelPermitData                      qwen3-14b  0.00005       64.0         ['activity']  ['accumulated_time']           4   0.6782          4  0.3206                BPI20_TPD_spark_001
# 234    BPI20TravelPermitData                      qwen3-14b   0.0005       64.0         ['activity']  ['accumulated_time']           5   0.6599          5  0.3301                BPI20_TPD_spark_001
# 235    BPI20TravelPermitData                      qwen3-14b    0.005       64.0         ['activity']  ['accumulated_time']           5   0.7387          5  0.3947                BPI20_TPD_spark_001
# 236    BPI20TravelPermitData                       qwen3-4b  0.00005       64.0         ['activity']  ['accumulated_time']           5   0.6716          5  0.3127                BPI20_TPD_spark_001
# ...
# 241    BPI20TravelPermitData                       qwen3-8b    0.005       32.0         ['activity']  ['accumulated_time']           1   0.7079          1  0.3691                BPI20_TPD_spark_001
#
#       total_params trainable_params embedding_size best_run_id
# 0                -                -              -         NaN
# 1        1332391.0        1332391.0              -    91m5859t
# 2        5024039.0        5024039.0              -    r34fp8v3
# 3       38399527.0       38399527.0              -    n874h7r2
# 4       19485223.0       19485223.0              -    tg0bk59x
# 5         221351.0         221351.0              -    ti3e5ttk
# 6         371303.0         371303.0              -    hv8myqd2
# 7       85910823.0       85910823.0              -    50yci2av
# 8      124504359.0          64551.0              -    c947ecdg
# 9      124504359.0          64551.0              -    jyb5k3cq
# 10     124504359.0          64551.0          768.0    8eqccqze
# 11     774137639.0         107559.0              -    qv5du45c
# 12     774137639.0         107559.0              -    8cc7im30
# 13     774137639.0         107559.0              -    s41y38iv
# 14     354909223.0          86055.0              -    ig5x2z3i
# 15     354909223.0          86055.0              -    512b6mnw
# 16     354909223.0          86055.0              -    a56yup1h
# 17      38647335.0          43047.0              -    jxt1xv0n
# 18      38647335.0          43047.0              -    vyp7dqs1
# 19      38647335.0          43047.0          512.0    p5p0kyzf
# 20    1557745639.0         134439.0              -    94pntaod
# 21    1557745639.0         134439.0              -    3itwdv79
# 22    1557745639.0         134439.0              -    tcbucblf
# 23     596135975.0         151591.0         1024.0    dhkqz419
# 24     596135975.0         151591.0         1024.0    5x3fy6nt
# 25     596135975.0         151591.0         1024.0    sd01vly9
# 26    1720747047.0         295975.0         2048.0    w4v51kr8
# 27    1720747047.0         295975.0         2048.0    2lowoz1w
# 28    1720747047.0         295975.0         2048.0    8eld88cz
# 29   13990824999.0         855079.0         5120.0    gevt9gv7
# 30   13990824999.0         855079.0         5120.0    p3vdwx71
# 31    4022683175.0         411175.0         2560.0    cl93vb2d
# 32    4022683175.0         411175.0         2560.0    o3986t7l
# 33    4022683175.0         411175.0         2560.0    58hcflzv
# 34    7568749607.0         652327.0         4096.0    tm9w346e
# 35    7568749607.0         652327.0         4096.0    50unngpx
# 36    7568749607.0         652327.0         4096.0    b4nm365x
# 37        248427.0         248427.0          100.0    t2920x0p
# 38       1332391.0        1332391.0          128.0    0p0oghx7
# 39       5024039.0        5024039.0          256.0    l0hr46n4
# 40      38399527.0       38399527.0          512.0    nikbc8ii
# 41      19485223.0       19485223.0          512.0    2y9qz90m
# 42        221351.0         221351.0           64.0    3ghyenan
# 43        371303.0         371303.0           64.0    20qb3zqs
# 44      85910823.0       85910823.0          768.0    0o742j82
# 45               -                -              -         NaN
# 46      38678327.0       38678327.0              -    y2kr2dds
# 47      19764023.0       19764023.0              -    u9xmgd7q
# 48      86328887.0       86328887.0              -    rnch5pie
# 49     124922423.0         482615.0              -    hmfklbvl
# 50     124922423.0         482615.0              -    o4txkhgj
# 51     124922423.0         482615.0          768.0    o5qvrgm9
# 52     774834231.0         804151.0              -    aeb4epzt
# 53     774834231.0         804151.0              -    buz9fs53
# 54     774834231.0         804151.0              -    u0pc3awg
# 55     355466551.0         643383.0              -    1xig0nsq
# 56     355466551.0         643383.0              -    pbevzqfw
# 57     355466551.0         643383.0              -    anvutuie
# 58      38926135.0         321847.0              -    myjdbwll
# 59      38926135.0         321847.0              -    24b0xrkd
# 60      38926135.0         321847.0              -    q1nxxzaa
# 61    1558616311.0        1005111.0              -    t5zvg8d2
# 62    1558616311.0        1005111.0              -    sjdzwr68
# 63    1558616311.0        1005111.0              -    xxestdyp
# 64     596693303.0         708919.0         1024.0    wv98xg4m
# 65     596693303.0         708919.0         1024.0    pmbp2b64
# 66     596693303.0         708919.0         1024.0    yv5o0gxc
# 67    1721861431.0        1410359.0         2048.0    75yg2jkh
# 68    1721861431.0        1410359.0         2048.0    izxcw360
# 69    1721861431.0        1410359.0         2048.0    zlvmd9bw
# 70    4024076087.0        1804087.0         2560.0    mgzu04rk
# 71    4024076087.0        1804087.0         2560.0    itega2gz
# 72    4024076087.0        1804087.0         2560.0    myfhftpf
# 73       1402295.0        1402295.0          128.0    x2rm9flx
# 74       5163575.0        5163575.0          256.0    ziwi7inx
# 75      38678327.0       38678327.0          512.0    0shcg7vj
# 76      19764023.0       19764023.0          512.0    0quza70u
# 77        256439.0         256439.0           64.0    k3rnaxp6
# 78        406391.0         406391.0           64.0    ivtohdoe
# 79      86328887.0       86328887.0          768.0    rodphc6q
# 80               -                -              -         NaN
# 81       1338816.0        1338816.0              -    w6s2kedf
# 82       5036864.0        5036864.0              -    ryejdbu6
# 83      38425152.0       38425152.0              -    agozhrdi
# 84      19510848.0       19510848.0              -    qai5kgmk
# 85        224576.0         224576.0              -    ha6cp7o9
# 86        374528.0         374528.0              -    b3j1xll4
# 87      85949248.0       85949248.0              -    hkilj4nu
# 88     124542784.0         102976.0              -    okk5wf67
# 89     124542784.0         102976.0              -    033fslk9
# 90     124542784.0         102976.0          768.0    y6ggwa2w
# 91     774201664.0         171584.0         1280.0    x70r3ay1
# 92     774201664.0         171584.0         1280.0    lgq149ob
# 93     774201664.0         171584.0              -    3rx88mm2
# 94     354960448.0         137280.0         1024.0    zrszghnd
# 95     354960448.0         137280.0         1024.0    hk5f1aq7
# 96     354960448.0         137280.0              -    l7i5txo9
# 97      38672960.0          68672.0          512.0    l9m2jhtg
# 98      38672960.0          68672.0              -    ajttzt9u
# 99      38672960.0          68672.0              -    8hlbk8oi
# 100   1557825664.0         214464.0              -    s3zuig1b
# 101   1557825664.0         214464.0              -    qlls1xio
# 102    596187200.0         202816.0         1024.0    ymptzw66
# 103    596187200.0         202816.0         1024.0    3y2w21l1
# 104    596187200.0         202816.0         1024.0    pybcr030
# 105   1720849472.0         398400.0         2048.0    xml6lntm
# 106   1720849472.0         398400.0         2048.0    cdo8hv8z
# 107   1720849472.0         398400.0         2048.0    0htgmm95
# 108   4022811200.0         539200.0         2560.0    b9d8q9n4
# 109   4022811200.0         539200.0         2560.0    zx31au1u
# 110   4022811200.0         539200.0         2560.0    kknm6n5z
# 111      1338816.0        1338816.0          128.0    srel296r
# 112      5036864.0        5036864.0          256.0    a2n0rfgw
# 113     38425152.0       38425152.0          512.0    texklhu9
# 114     19510848.0       19510848.0          512.0    popq6vhk
# 115       224576.0         224576.0           64.0    j0e1f4np
# 116       374528.0         374528.0           64.0    qo2ivn61
# 117     85949248.0       85949248.0          768.0    t6gwpdj0
# 118              -                -              -         NaN
# 119      1333419.0        1333419.0              -    vwb1ygv5
# 120      5026091.0        5026091.0              -    wx8ymlm2
# 121     38403627.0       38403627.0              -    fzk33jt3
# 122     19489323.0       19489323.0              -    2fd5dpas
# 123       221867.0         221867.0              -    jns7mvco
# 124       371819.0         371819.0              -    bbgljnhz
# 125     85916971.0       85916971.0              -    76co2s7o
# 126    124510507.0          70699.0          768.0    3dbc802v
# 127    124510507.0          70699.0          768.0    q9127opf
# 128    354917419.0          94251.0         1024.0    75u8htqu
# 129    354917419.0          94251.0         1024.0    yhoa0ujr
# 130     38651435.0          47147.0          512.0    2xgeguu4
# 131     38651435.0          47147.0          512.0    db3osyz8
# 132    596144171.0         159787.0         1024.0    rtn3dhpt
# 133    596144171.0         159787.0         1024.0    48l2q5vc
# 134     38403627.0       38403627.0          512.0    w2li7pw4
# 135     85916971.0       85916971.0          768.0    hzwy4aq5
# 136              -                -              -         NaN
# 137      1330592.0        1330592.0              -    j6abinjx
# 138      5020448.0        5020448.0              -    1oxaglwr
# 139     38392352.0       38392352.0              -    8xzlnq4e
# 140     19478048.0       19478048.0              -    hwtjugzx
# 141       220448.0         220448.0              -    mpz28dt2
# 142       370400.0         370400.0              -    5gnt2y9i
# 143     85900064.0       85900064.0              -    1yx127fj
# 144    124493600.0          53792.0              -    5ky9b6qc
# 145    124493600.0          53792.0              -    amv12yeq
# 146    124493600.0          53792.0              -    p1muojki
# 147    774119712.0          89632.0              -    23ez4h0a
# 148    774119712.0          89632.0              -    gtzbc1cr
# 149    774119712.0          89632.0              -    sf2rqok1
# 150    354894880.0          71712.0              -    7umh5hzs
# 151    354894880.0          71712.0              -    kgs94uwy
# 152    354894880.0          71712.0              -    cyfjmlad
# 153     38640160.0          35872.0              -    xbtx91px
# 154     38640160.0          35872.0              -    h1zjigfh
# 155     38640160.0          35872.0          512.0    8k70s361
# 156   1557723232.0         112032.0              -    i1iqqjy6
# 157   1557723232.0         112032.0              -    f2sd95b0
# 158   1557723232.0         112032.0              -    ojpl18v0
# 159    596121632.0         137248.0         1024.0    ngprbbp8
# 160    596121632.0         137248.0         1024.0    ywes38s0
# 161    596121632.0         137248.0         1024.0    8c0eqwid
# 162   1720718368.0         267296.0         2048.0    gvu42j8o
# 163   1720718368.0         267296.0         2048.0    5w620vei
# 164   1720718368.0         267296.0         2048.0    qjg0a8t1
# 165   4022647328.0         375328.0         2560.0    2azqkoi3
# 166   4022647328.0         375328.0         2560.0    spipazhe
# 167   4022647328.0         375328.0         2560.0    1zuy7coa
# 168   7568692256.0         594976.0         4096.0    0j1cip2u
# 169   7568692256.0         594976.0         4096.0    jfhwp4t8
# 170   7568692256.0         594976.0         4096.0    729fvoyp
# 171              -                -              -         NaN
# 172      1327251.0        1327251.0              -    63jczrjw
# 173      5013779.0        5013779.0              -    heh5kx1k
# 174     38379027.0       38379027.0              -    bwwxvsfj
# 175     19464723.0       19464723.0              -    bcqq6dhd
# 176       218771.0         218771.0              -    vufrg1ip
# 177       368723.0         368723.0              -    sw90mpik
# 178     85880083.0       85880083.0              -    2m8xt71l
# 179    124473619.0          33811.0              -    1kee6wgm
# 180    124473619.0          33811.0              -    hni6x9i8
# 181    124473619.0          33811.0          768.0    yl24edey
# 182    774086419.0          56339.0              -    06fyxgvy
# 183    774086419.0          56339.0              -    9e3wxoef
# 184    774086419.0          56339.0              -    vmhbih75
# 185    354868243.0          45075.0              -    2nv5ivyg
# 186    354868243.0          45075.0              -    e6p6z89m
# 187    354868243.0          45075.0              -    ktue8aks
# 188     38626835.0          22547.0              -    i7ij0k8r
# 189     38626835.0          22547.0              -    rgozvc6r
# 190     38626835.0          22547.0              -    kve8knf5
# 191   1557681619.0          70419.0              -    49m73snz
# 192   1557681619.0          70419.0              -    qiwui7hg
# 193   1557681619.0          70419.0              -    1qkinc1l
# 194    596094995.0         110611.0         1024.0    v71num98
# 195    596094995.0         110611.0         1024.0    n4rptjqu
# 196    596094995.0         110611.0         1024.0    ewv3plr9
# 197   1720665107.0         214035.0         2048.0    49ympvlu
# 198   1720665107.0         214035.0         2048.0    4voyfea7
# 199   1720665107.0         214035.0         2048.0    x47tyevm
# 200   4022580755.0         308755.0         2560.0    0pi5tpg7
# 201   4022580755.0         308755.0         2560.0    unkgbiww
# 202   4022580755.0         308755.0         2560.0    9ft0ke3l
# 203              -                -              -         NaN
# 204      1335989.0        1335989.0              -    tqhcpiu3
# 205      5031221.0        5031221.0              -    o9h0uz9n
# 206     38413877.0       38413877.0              -    acn730f9
# 207     19499573.0       19499573.0              -    6leoxlk9
# 208       223157.0         223157.0              -    yxrh7a1n
# 209       373109.0         373109.0              -    7iyj0a9r
# 210     85932341.0       85932341.0              -    n0mh700g
# 211    124525877.0          86069.0          768.0    2h5otfl0
# 212    124525877.0          86069.0              -    0x3ez28j
# 213    124525877.0          86069.0              -    z704n1ig
# 214    774173493.0         143413.0              -    v6fg9dyn
# 215    774173493.0         143413.0              -    qm8wup6s
# 216    774173493.0         143413.0              -    ukbxukzw
# 217    354937909.0         114741.0              -    43b3ek7q
# 218    354937909.0         114741.0              -    59mmpob8
# 219    354937909.0         114741.0              -    gp0rpsxz
# 220     38661685.0          57397.0              -    qj2u3tvt
# 221     38661685.0          57397.0              -    s4eztu06
# 222     38661685.0          57397.0              -    xkthr7ip
# 223   1557790453.0         179253.0              -    d4n5gueo
# 224   1557790453.0         179253.0              -    ay8xlxlr
# 225   1557790453.0         179253.0              -    srd83cbm
# 226    596164661.0         180277.0         1024.0    2ww5x0lt
# 227    596164661.0         180277.0         1024.0    1ma820zk
# 228    596164661.0         180277.0         1024.0    8hfqh3e4
# 229   1720804405.0         353333.0         2048.0    dc3m3yrq
# 230   1720804405.0         353333.0         2048.0    ncvhdcnz
# 231   1720804405.0         353333.0         2048.0    keur9j0s
# 232  13990968373.0         998453.0         5120.0    38g73rg7
# 233  13990968373.0         998453.0         5120.0    scg3l20n
# 234  13990968373.0         998453.0         5120.0    6f2iuaod
# 235  13990968373.0         998453.0         5120.0    hwaz00ty
# 236   4022754869.0         482869.0         2560.0    k08ojayh
# 237   4022754869.0         482869.0         2560.0    j2xn3ahk
# 238   4022754869.0         482869.0         2560.0    6f7aai8d
# 239   7568864309.0         767029.0         4096.0    ctmdsfn0
# 240   7568864309.0         767029.0         4096.0    awj5zkjj
# 241   7568864309.0         767029.0         4096.0    zkmmptow

# %%
# Extend aggregation to include std
agg = (
    df.groupby(GROUP_COLS, dropna=False)
      .agg({
          "best_test_final_next_activity_acc": ["count", "mean", "std"],
          "best_test_final_next_activity_f1": ["count", "mean", "std"],
      })
)

# Flatten columns
agg.columns = [
    f"{METRICS[m]}_{stat}"
    for (m, stat) in agg.columns
]

# Join descriptors + best run id as before
summary = agg
if EXTRA_COLS:
    summary = summary.join(
        df.groupby(GROUP_COLS, dropna=False)[EXTRA_COLS].first()
    )

best_idx = df.groupby(GROUP_COLS, dropna=False)["best_test_final_next_activity_acc"].idxmax()
best_runs = df.loc[best_idx].set_index(GROUP_COLS)["id"].rename("best_run_id")

summary = summary.join(best_runs).reset_index()

# %%
best_per_log_backbone = (
    summary.sort_values(
        ["log", "backbone", "f1_mean"],
        ascending=[True, True, False],
        na_position="last",
    )
    .groupby(["log", "backbone"], dropna=False, as_index=False)
    .head(1)
)

# %%
# COMPLETE CODE: aggregate (mean/std), pick best lr per (log, backbone) by f1_mean,
# then plot all logs in a 2-column matrix with:
#  - bottom x-axis: backbone names (diagonal)
#  - top x-axis: decade ticks labeled 1e3, 1e4, ...
#  - colors: Accuracy=blue, F1=orange
#  - line styles: GPT=solid, Qwen=dashed
#  - baseline_transition_frequency: horizontal dotted lines (acc + f1)
#  - shared/global x- and y-axis ranges across all subplots

import json
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
from pathlib import Path


def compute_log_padded_range(x_vals, pad_decades=0.15):
    xmin = np.min(x_vals)
    xmax = np.max(x_vals)

    log_min = np.log10(xmin)
    log_max = np.log10(xmax)

    log_pad = pad_decades * (log_max - log_min)
    return (
        10 ** (log_min - log_pad),
        10 ** (log_max + log_pad),
    )



# ----------------------------
# 1) Configuration
# ----------------------------
METRICS = {
    "best_test_final_next_activity_acc": "acc",
    "best_test_final_next_activity_f1": "f1",
}

GROUP_COLS = ["log", "backbone", "lr", "batch_size", "categorical_features", "continuous_features"]
EXTRA_COLS = ["total_params", "trainable_params", "embedding_size"]


# ----------------------------
# 2) Helpers
# ----------------------------
def make_hashable(x):
    """Convert unhashable objects (list/dict/set) into a stable string for grouping."""
    if pd.isna(x):
        return pd.NA
    if isinstance(x, (list, tuple)):
        return json.dumps(x, sort_keys=True)
    if isinstance(x, set):
        return json.dumps(sorted(list(x)))
    if isinstance(x, dict):
        return json.dumps(x, sort_keys=True)
    return x

def backbone_family(name: str) -> str:
    """Classify backbone into family for linestyle."""
    s = str(name)
    return "qwen" if s.startswith("qwen") else "gpt"

def backbone_source(name: str) -> str:
    s = str(name)
    if s.startswith("scratch_"):
        return "scratch"
    if s.startswith("distill_"):
        return "distill"
    return "finetune"

def backbone_display_label(name: str) -> str:
    s = str(name)
    if s.startswith("scratch_"):
        return s.split("scratch_", 1)[1]
    if s.startswith("distill_"):
        return s.split("distill_", 1)[1]
    return s

def _format_abbrev_tick(v: float) -> str:
    """Format numeric value as short label (e.g., 1K, 10K, 1M)."""
    v = float(v)
    if v >= 1e9:
        return f"{v/1e9:g}B"
    if v >= 1e6:
        return f"{v/1e6:g}M"
    if v >= 1e3:
        return f"{v/1e3:g}K"
    return f"{v:g}"


def _decade_ticks(xmin: float, xmax: float) -> np.ndarray:
    """Return decade ticks within [xmin, xmax] for a log-scale axis."""
    kmin = int(np.floor(np.log10(xmin)))
    kmax = int(np.ceil(np.log10(xmax)))
    ticks = [10**k for k in range(kmin, kmax + 1)]
    ticks = [t for t in ticks if xmin <= t <= xmax]
    return np.asarray(ticks, dtype=float)


def apply_single_axis_xlabels(
    ax,
    numeric_ticks,
    backbone_xticks=None,
    backbone_labels=None,
    show_backbone_labels=False,
):
    """Use one x-axis: major ticks for numeric labels, minor ticks for backbone labels."""
    numeric_ticks = np.asarray(numeric_ticks, dtype=float)
    if numeric_ticks.size > 0:
        numeric_ticks = np.unique(np.sort(numeric_ticks))
        ax.xaxis.set_major_locator(mticker.FixedLocator(numeric_ticks))
        ax.xaxis.set_major_formatter(mticker.FixedFormatter([_format_abbrev_tick(v) for v in numeric_ticks]))

    # Place numeric labels above the x-axis line.
    ax.tick_params(axis="x", which="major", pad=-12, length=3)

    if show_backbone_labels and backbone_xticks is not None and backbone_labels is not None and len(backbone_xticks) > 0:
        bx = np.asarray(backbone_xticks, dtype=float)
        order = np.argsort(bx)
        bx = bx[order]
        labels = [str(backbone_labels[i]) for i in order]

        # Deduplicate by x, keeping first label.
        seen = set()
        bx_unique = []
        lbl_unique = []
        for x, lbl in zip(bx, labels):
            if float(x) in seen:
                continue
            seen.add(float(x))
            bx_unique.append(float(x))
            lbl_unique.append(lbl)

        ax.xaxis.set_minor_locator(mticker.FixedLocator(bx_unique))
        ax.xaxis.set_minor_formatter(mticker.FixedFormatter(lbl_unique))
        ax.tick_params(axis="x", which="minor", pad=14, length=0, labelbottom=True)
        for lbl in ax.get_xminorticklabels():
            lbl.set_rotation(45)
            lbl.set_ha("right")
    else:
        ax.xaxis.set_minor_locator(mticker.NullLocator())
        ax.xaxis.set_minor_formatter(mticker.NullFormatter())
# ----------------------------
# 3) Build summary with mean/std
# ----------------------------
def build_summary_with_std(runs: pd.DataFrame) -> pd.DataFrame:
    extra_cols = [c for c in EXTRA_COLS if c in runs.columns]
    tmp = runs.copy()

    # Ensure grouping columns are hashable
    for c in GROUP_COLS:
        if c in tmp.columns:
            tmp[c] = tmp[c].map(make_hashable)

    keep_cols = [c for c in GROUP_COLS if c in tmp.columns] + ["id"] + list(METRICS.keys()) + extra_cols
    df = tmp[keep_cols].copy()

    # metrics numeric
    for m in METRICS:
        df[m] = pd.to_numeric(df[m], errors="coerce")

    # keep rows with at least one metric
    df = df.dropna(subset=list(METRICS.keys()), how="all")

    # Aggregate count + mean + std (KEEP NaN groups)
    agg = (
        df.groupby(GROUP_COLS, dropna=False)
          .agg({m: ["count", "mean", "std"] for m in METRICS})
    )

    # Flatten columns -> acc_count/mean/std, f1_count/mean/std
    agg.columns = [f"{METRICS[m]}_{stat}" for (m, stat) in agg.columns]

    # Descriptors (KEEP NaN groups)
    if extra_cols:
        descriptors = df.groupby(GROUP_COLS, dropna=False)[extra_cols].first()
        summary = agg.join(descriptors)
    else:
        summary = agg

    # Best run id (choose priority metric)
    BEST_METRIC = "best_test_final_next_activity_acc"
    best_idx = df.groupby(GROUP_COLS, dropna=False)[BEST_METRIC].idxmax()
    best_runs = df.loc[best_idx].set_index(GROUP_COLS)["id"].rename("best_run_id")

    summary = summary.join(best_runs).reset_index()

    # Rename counts
    summary = summary.rename(columns={"acc_count": "acc_n_runs", "f1_count": "f1_n_runs"})

    # Ensure numeric for plotting columns
    for col in ["acc_mean", "acc_std", "f1_mean", "f1_std", "acc_n_runs", "f1_n_runs", "total_params"]:
        if col in summary.columns:
            summary[col] = pd.to_numeric(summary[col], errors="coerce")

    return summary


# ----------------------------
# 4) Select best lr per (log, backbone) by highest f1_mean
# ----------------------------
def select_best_lr_per_log_backbone(summary: pd.DataFrame) -> pd.DataFrame:
    s = summary.copy()
    s["f1_mean"] = pd.to_numeric(s["f1_mean"], errors="coerce")
    if "acc_mean" in s.columns:
        s["acc_mean"] = pd.to_numeric(s["acc_mean"], errors="coerce")

    sort_cols = ["log", "backbone", "f1_mean"]
    ascending = [True, True, False]

    # tie-breakers
    if "acc_mean" in s.columns:
        sort_cols.append("acc_mean"); ascending.append(False)
    if "f1_n_runs" in s.columns:
        sort_cols.append("f1_n_runs"); ascending.append(False)
    if "lr" in s.columns:
        sort_cols.append("lr"); ascending.append(True)

    return (
        s.sort_values(sort_cols, ascending=ascending, na_position="last")
         .groupby(["log", "backbone"], dropna=False, as_index=False)
         .head(1)
         .reset_index(drop=True)
    )


# ----------------------------
# 5) Plot matrix for all logs (2 columns)
# ----------------------------
def plot_all_logs_matrix(
    best_df: pd.DataFrame,
    ncols: int = 2,
    x_axis: str = "total_params",
    save_path: str | None = None,
    dpi: int = 300,
    plots_per_page: int = 4,
):

    logs = sorted(best_df["log"].dropna().unique())
    nlogs = len(logs)

    if ncols != 2:
        raise ValueError("This layout expects ncols=2 for a 2x2 page.")
    if plots_per_page != 4:
        raise ValueError("This layout expects plots_per_page=4 for a 2x2 page.")

    # ---------- GLOBAL AXIS RANGES (shared across all pages) ----------
    x_vals = best_df[x_axis].dropna().astype(float).values
    global_xmin, global_xmax = compute_log_padded_range(x_vals)

    y_candidates = []
    for col in ["acc_mean", "f1_mean"]:
        if col in best_df.columns:
            y_candidates.extend(best_df[col].dropna().astype(float).values)

    # Keep y-range based on means only for cleaner, more legible plots.

    global_ymin = float(np.min(y_candidates))
    global_ymax = float(np.max(y_candidates))
    y_pad = 0.02 * (global_ymax - global_ymin) if global_ymax > global_ymin else 0.01
    global_ymin -= y_pad
    global_ymax += y_pad

    ACC_COLORS_BY_SOURCE = {
        "scratch": "#1f77b4",   # blue
        "distill": "#1b5e20",   # dark green
        "finetune": "#424242",  # dark grey
    }
    F1_COLORS_BY_SOURCE = {
        "scratch": "#800000",   # maroon
        "distill": "#ff7f0e",   # orange
        "finetune": "#d62728",  # red
    }

    nrows = 2
    total_pages = max(1, math.ceil(nlogs / plots_per_page))

    for page_idx in range(total_pages):
        page_start = page_idx * plots_per_page
        page_end = min(page_start + plots_per_page, nlogs)
        page_logs = logs[page_start:page_end]
        n_page_logs = len(page_logs)

        fig, axes = plt.subplots(
            nrows=nrows,
            ncols=ncols,
            figsize=(13, 6.2 * nrows),
            sharex=True,
            sharey=True,
        )
        axes = np.array(axes).reshape(nrows, ncols)

        legend_handles = {}

        # Lowest visible subplot per column gets x labels/ticks.
        bottom_row_per_col = {}
        fallback_backbone_by_col = {}

        for col in range(ncols):
            candidates_visible = []
            candidates_with_data = []
            for row in range(nrows):
                idx = row * ncols + col
                if idx >= n_page_logs:
                    continue
                candidates_visible.append(row)
                log = page_logs[idx]
                log_data = best_df[
                    (best_df["log"] == log)
                    & (best_df["backbone"] != "baseline_transition_frequency")
                ].dropna(subset=[x_axis])
                if not log_data.empty:
                    candidates_with_data.append(row)

            if candidates_visible:
                bottom_row_per_col[col] = max(candidates_visible)

            if candidates_with_data:
                src_row = max(candidates_with_data)
                src_idx = src_row * ncols + col
                src_log = page_logs[src_idx]
                src_data = best_df[
                    (best_df["log"] == src_log)
                    & (best_df["backbone"] != "baseline_transition_frequency")
                ].dropna(subset=[x_axis]).sort_values(x_axis)
                tick_df = src_data[[x_axis, "backbone"]].drop_duplicates(subset=[x_axis], keep="first")
                fallback_backbone_by_col[col] = (
                    tick_df[x_axis].astype(float).values,
                    [backbone_display_label(v) for v in tick_df["backbone"].tolist()],
                )

        numeric_ticks = _decade_ticks(global_xmin, global_xmax)

        for i, log in enumerate(page_logs):
            r, c = divmod(i, ncols)
            ax = axes[r, c]

            data_all = best_df[best_df["log"] == log]
            baseline = data_all[data_all["backbone"] == "baseline_transition_frequency"]
            data = data_all[data_all["backbone"] != "baseline_transition_frequency"]

            data = data.dropna(subset=[x_axis]).sort_values(x_axis)

            # GPT / QWEN with source markers: scratch=triangle, distill=square, finetune=circle
            marker_by_source = {"scratch": "^", "distill": "s", "finetune": "o"}
            data = data.copy()
            data["_source"] = data["backbone"].map(backbone_source)

            for fam, linestyle in [("gpt", "-"), ("qwen", "--")]:
                fam_data = data[data["backbone"].map(lambda b: backbone_family(b) == fam)]
                if fam_data.empty:
                    continue

                for src_name, marker in marker_by_source.items():
                    fam_src = fam_data[fam_data["_source"] == src_name]
                    if fam_src.empty:
                        continue

                    x = fam_src[x_axis].astype(float).values
                    acc_color = ACC_COLORS_BY_SOURCE[src_name]
                    f1_color = F1_COLORS_BY_SOURCE[src_name]

                    h_acc, = ax.plot(
                        x,
                        fam_src["acc_mean"],
                        color=acc_color,
                        linestyle=linestyle,
                        marker=marker,
                        label=f"Accuracy ({fam.upper()}, {src_name})",
                    )

                    h_f1, = ax.plot(
                        x,
                        fam_src["f1_mean"],
                        color=f1_color,
                        linestyle=linestyle,
                        marker=marker,
                        label=f"F1 ({fam.upper()}, {src_name})",
                    )

                    legend_handles.setdefault(f"Accuracy ({fam.upper()}, {src_name})", h_acc)
                    legend_handles.setdefault(f"F1 ({fam.upper()}, {src_name})", h_f1)

            if not baseline.empty:
                b = baseline.iloc[0]
                if pd.notna(b.get("acc_mean", np.nan)):
                    h = ax.axhline(float(b["acc_mean"]), color="#1f77b4", linestyle=":", linewidth=2)
                    legend_handles.setdefault("Baseline Accuracy", h)
                if pd.notna(b.get("f1_mean", np.nan)):
                    h = ax.axhline(float(b["f1_mean"]), color="#ff7f0e", linestyle=":", linewidth=2)
                    legend_handles.setdefault("Baseline F1", h)

            ax.set_xscale("log")
            ax.set_xlim(global_xmin, global_xmax)
            ax.set_ylim(global_ymin, global_ymax)

            backbone_xticks = np.array([], dtype=float)
            backbone_labels = []
            if not data.empty:
                tick_df = (
                    data[[x_axis, "backbone"]]
                    .dropna(subset=[x_axis])
                    .sort_values(x_axis)
                    .drop_duplicates(subset=[x_axis], keep="first")
                )
                backbone_xticks = tick_df[x_axis].astype(float).values
                backbone_labels = [backbone_display_label(v) for v in tick_df["backbone"].tolist()]
            elif c in fallback_backbone_by_col:
                backbone_xticks, backbone_labels = fallback_backbone_by_col[c]

            apply_single_axis_xlabels(
                ax,
                numeric_ticks=numeric_ticks,
                backbone_xticks=backbone_xticks,
                backbone_labels=backbone_labels,
                show_backbone_labels=(r == bottom_row_per_col.get(c) and len(backbone_xticks) > 0),
            )
            if r == bottom_row_per_col.get(c):
                ax.tick_params(axis="x", which="major", labelbottom=True)

            ax.set_title(str(log))
            ax.grid(True, which="both", linestyle="--", linewidth=0.5)

            if c == 0:
                ax.set_ylabel("Metric value")
            if r == bottom_row_per_col.get(c):
                ax.set_xlabel(f"{x_axis} (log scale)")

        for j in range(n_page_logs, nrows * ncols):
            axes.flat[j].axis("off")

        fig.legend(
            legend_handles.values(),
            legend_handles.keys(),
            loc="upper center",
            ncol=3,
            frameon=True,
            bbox_to_anchor=(0.5, 1.02),
        )

        plt.tight_layout(rect=[0, 0.11, 1, 0.95])

        if save_path is not None:
            save_path_obj = Path(save_path)
            page_suffix = f"_page{page_idx + 1}" if total_pages > 1 else ""
            page_path = save_path_obj.with_name(f"{save_path_obj.stem}{page_suffix}{save_path_obj.suffix}")
            plt.savefig(page_path, dpi=dpi, bbox_inches="tight")

        plt.show()

# %%
# ----------------------------
# 6) RUN IT
# ----------------------------
# Assumes you already have a DataFrame named `runs`.
summary = build_summary_with_std(runs)
best_per_log_backbone = select_best_lr_per_log_backbone(summary)

save_path = plots_dir / "all_logs_trainable_params.png"

plot_all_logs_matrix(
    best_per_log_backbone,
    x_axis="trainable_params",
    save_path=str(save_path),
)

# %%
save_path = plots_dir / "all_logs_total_params.png"

plot_all_logs_matrix(
    best_per_log_backbone,
    x_axis="total_params",
    save_path=str(save_path),
)

# %%
runs.columns
# Out:
# Index(['id', 'name', 'r', 'lr', 'log', 'device', 'epochs', 'compile',
#        'n_heads', 'backbone',
#        ...
#        'val_next_activity_CE_loss', 'val_next_activity_KL_loss',
#        'val_next_activity_total_loss', 'best_test_final_next_activity_auroc',
#        'test_next_activity_auroc', 'train_next_activity_auroc',
#        'val_next_activity_auroc', 'seed', 'prediction_table',
#        'transition_table'],
#       dtype='str', length=120)
