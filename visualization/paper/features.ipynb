# %%
import sys
from pathlib import Path

current_dir = Path.cwd().resolve()
# walks upward until it finds a directory containing ppm/
PROJECT_ROOT = next(
    (p for p in (current_dir, *current_dir.parents) if (p / "ppm").is_dir()),
    current_dir,
)

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

import pandas as pd
from ppm.wandb_utils import load_multiple_experiments

plots_dir = PROJECT_ROOT / "plots/features"
plots_dir.mkdir(parents=True, exist_ok=True)

# %%
PROJECTS=[
    "BPI12_spark_freeze_001",
    "BBPI12_spark_freeze_001",
    "activity_only_bpi12_002",
    "extra_features_bpi12_001",
    "extra_features_bpi12_003",
    "activity_only_unfreeze_last_bpi12_002",
    "extra_feature_bpi12_unfreeze_last_001",
    "gpt2_unfreeze_last_002",
    "extra_feature_bpi12_unfreeze_last2_001",
    "extra_features_bpi12_unfreeze_last2_001",
    "gpt2_unfreeze_last2_001",
    "extra_features_bpi12_unfreeze_last3_001",
    "extra_features_bpi12_unfreeze_last4_001",
    "extra_features_bpi20rfp_001",
    "extra_features_bpi20_rfp_002",
    "extra_features_bpi20rfp_unfreeze_last_001",
    "extra_features_unfreeze_last_bpi20_rfp_002",
    "extra_features_bpi20rfp_unfreeze_last2_001",
    "extra_features_bpi20rfp_unfreeze_last3_001",
    "extra_features_bpi20rfp_unfreeze_last4_001",
    "extra_features_bpi20_001",
    "extra_features_unfreeze_last_bpi20_001",
    "extra_features_bpi20ptc_unfreeze_last2_001",
    "extra_features_bpi20ptc_unfreeze_last3_001",
    "extra_features_bpi20ptc_unfreeze_last4_001",
]

runs_raw, _ = load_multiple_experiments(PROJECTS, force_update=False)
# Out:
# Fetched 8 runs and 156 history entries to /app/visualization/paper/metrics/BPI12_spark_freeze_001.db
# Fetched 2 runs and 36 history entries to /app/visualization/paper/metrics/BBPI12_spark_freeze_001.db
# Database already exists: /app/visualization/paper/metrics/activity_only_bpi12_002.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/paper/metrics/extra_features_bpi12_001.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/paper/metrics/extra_features_bpi12_003.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/paper/metrics/activity_only_unfreeze_last_bpi12_002.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/paper/metrics/extra_feature_bpi12_unfreeze_last_001.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/paper/metrics/gpt2_unfreeze_last_002.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/paper/metrics/extra_feature_bpi12_unfreeze_last2_001.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/paper/metrics/extra_features_bpi12_unfreeze_last2_001.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/paper/metrics/gpt2_unfreeze_last2_001.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/paper/metrics/extra_features_bpi12_unfreeze_last3_001.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/paper/metrics/extra_features_bpi12_unfreeze_last4_001.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/paper/metrics/extra_features_bpi20rfp_001.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/paper/metrics/extra_features_bpi20_rfp_002.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/paper/metrics/extra_features_bpi20rfp_unfreeze_last_001.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/paper/metrics/extra_features_unfreeze_last_bpi20_rfp_002.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/paper/metrics/extra_features_bpi20rfp_unfreeze_last2_001.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/paper/metrics/extra_features_bpi20rfp_unfreeze_last3_001.db
# Use force_update=True to re-fetch from wandb
# Database already exists: /app/visualization/paper/metrics/extra_features_bpi20rfp_unfreeze_last4_001.db
# Use force_update=True to re-fetch from wandb
# Fetched 55 runs and 863 history entries to /app/visualization/paper/metrics/extra_features_bpi20_001.db
# Fetched 40 runs and 809 history entries to /app/visualization/paper/metrics/extra_features_unfreeze_last_bpi20_001.db
# Fetched 25 runs and 613 history entries to /app/visualization/paper/metrics/extra_features_bpi20ptc_unfreeze_last2_001.db
# Fetched 25 runs and 608 history entries to /app/visualization/paper/metrics/extra_features_bpi20ptc_unfreeze_last3_001.db
# Fetched 25 runs and 642 history entries to /app/visualization/paper/metrics/extra_features_bpi20ptc_unfreeze_last4_001.db
# Loaded 767 runs from 25 experiments
# Datasets: ['BPI12', 'BPI20RequestForPayment', 'BPI20PrepaidTravelCosts', 'BPI20TravelPermitData']

# %%
import pandas as pd

pd.set_option("display.max_columns", None)   # show all columns
pd.set_option("display.width", None)         # don't wrap/truncate by width
pd.set_option("display.max_colwidth", None)  # optional: full cell content

runs_raw.columns
# Out:
# Index(['id', 'name', 'r', 'lr', 'log', 'device', 'epochs', 'compile',
#        'n_heads', 'backbone',
#        ...
#        'group', 'job_type', 'project', 'best_test_final_next_activity_auroc',
#        'test_next_activity_auroc', 'train_next_activity_auroc',
#        'val_next_activity_auroc', 'n_embd', 'n_head', 'block_size'],
#       dtype='str', length=101)

# %%
# prepocessing
runs = runs_raw.copy()

fine_tuning_col = "fine_tuning" if "fine_tuning" in runs.columns else "fine-tuning"
freeze_layers_col = "freeze_layers" if "freeze_layers" in runs.columns else "freeze-layers"
mask_no_finetuning = runs[fine_tuning_col].isna() | (runs[fine_tuning_col].astype(str) == "None")
runs.loc[mask_no_finetuning, freeze_layers_col] = "all"

# %% [markdown]
# ## Impact attributes

# %%
METRIC = "best_test_final_next_activity_acc"
#METRIC = "best_test_final_next_activity_f1"

for col in ["categorical_features", "continuous_features"]:
    if col in runs.columns:
        runs[col] = runs[col].astype(str)

GROUP_COLS = ["log", "backbone", "freeze_layers", "lr", "batch_size", "categorical_features", "continuous_features"]

EXTRA_COLS = ["project", "total_params", "trainable_params", "embedding_size"]
EXTRA_COLS = [c for c in EXTRA_COLS if c in runs.columns]  # only keep ones that exist

# Build df with everything we need
df = runs[GROUP_COLS + ["id", METRIC] + EXTRA_COLS].dropna(subset=[METRIC]).copy()
df[METRIC] = df[METRIC].astype(float)

# 1) Metric stats (ONLY from METRIC)
agg = (
    df.groupby(GROUP_COLS)[METRIC]
      .agg(["count", "mean", "std", "min", "max"])
      .rename(columns={
          "count": "n_runs",
          "mean": "acc_mean",
          "std": "acc_std",
          "min": "acc_min",
          "max": "acc_max",
      })
)

# 2) Add “descriptor” columns (not metric-related)
#    We assume these are constant within group; if not, we’ll detect it below.
descriptors = df.groupby(GROUP_COLS)[EXTRA_COLS].first() if EXTRA_COLS else None

# Optional: detect groups where descriptors are NOT constant
if EXTRA_COLS:
    nunique = df.groupby(GROUP_COLS)[EXTRA_COLS].nunique(dropna=False)
    bad = (nunique > 1).any(axis=1)
    if bad.any():
        print("Warning: some groups have varying descriptor values:")
        display(nunique[bad].reset_index())

# 3) Best run id per group (based on METRIC)
best_idx = df.groupby(GROUP_COLS)[METRIC].idxmax()
best_runs = df.loc[best_idx].set_index(GROUP_COLS)["id"].rename("best_run_id")

# 4) Combine
summary = agg
if descriptors is not None:
    summary = summary.join(descriptors)

summary = summary.join(best_runs).reset_index()
summary["n_runs"] = summary["n_runs"].astype(int)

for col in ["acc_mean", "acc_std", "acc_min", "acc_max"]:
    summary[col] = summary[col].map(lambda x: f"{x:.4f}")

summary = summary.sort_values(GROUP_COLS).reset_index(drop=True)

with pd.option_context("display.max_rows", None, "display.max_columns", None, "display.width", 200):
    display(summary)
# Out:
# Warning: some groups have varying descriptor values:
#                       log backbone freeze_layers     lr  batch_size  \
# 0                   BPI12     gpt2            -1  0.005          64
# 1                   BPI12     gpt2         -1,-2  0.005          64
# 2                   BPI12     gpt2         -1,-2  0.005          64
# 3                   BPI12     gpt2         -1,-2  0.005          64
# 4                   BPI12     gpt2         -1,-2  0.005          64
# 5                   BPI12     gpt2          1,-1  0.005          64
# 6  BPI20RequestForPayment     gpt2            -1  0.005          64
# 7  BPI20RequestForPayment     gpt2            -1  0.005          64
# 8  BPI20RequestForPayment     gpt2            -1  0.005          64
#
#        categorical_features             continuous_features  project  \
# 0              ['activity']            ['accumulated_time']        2
# 1  ['activity', 'resource']  ['accumulated_time', 'amount']        2
# 2  ['activity', 'resource']            ['accumulated_time']        2
# 3              ['activity']  ['accumulated_time', 'amount']        2
# 4              ['activity']            ['accumulated_time']        3
# 5  ['activity', 'resource']  ['accumulated_time', 'amount']        2
# 6  ['activity', 'resource']            ['accumulated_time']        2
# 7              ['activity']            ['accumulated_time']        2
# 8              ['activity']                              []        2
#
#    total_params  trainable_params  embedding_size
# 0             1                 1               1
# 1             1                 1               1
# 2             1                 1               1
# 3             1                 1               1
# 4             1                 1               1
# 5             1                 1               1
# 6             1                 1               1
# 7             1                 1               1
# 8             1                 1               1
#                         log backbone freeze_layers     lr  batch_size      categorical_features             continuous_features  n_runs acc_mean acc_std acc_min acc_max  \
# 0                     BPI12     gpt2            -1  0.005          64  ['activity', 'resource']  ['accumulated_time', 'amount']      10   0.8354  0.0051  0.8275  0.8433
# 1                     BPI12     gpt2            -1  0.005          64  ['activity', 'resource']            ['accumulated_time']      10   0.8290  0.0089  0.8143  0.8439
# 2                     BPI12     gpt2            -1  0.005          64              ['activity']  ['accumulated_time', 'amount']      10   0.8022  0.0153  0.7743  0.8155
# 3                     BPI12     gpt2            -1  0.005          64              ['activity']            ['accumulated_time']      20   0.8038  0.0089  0.7788  0.8165
# 4                     BPI12     gpt2            -1  0.005          64              ['activity']                              []      10   0.7860  0.0146  0.7622  0.8033
# 5                     BPI12     gpt2         -1,-2  0.005          64  ['activity', 'resource']  ['accumulated_time', 'amount']      15   0.8342  0.0089  0.8176  0.8495
# 6                     BPI12     gpt2         -1,-2  0.005          64  ['activity', 'resource']            ['accumulated_time']      15   0.8314  0.0056  0.8206  0.8399
# 7                     BPI12     gpt2         -1,-2  0.005          64              ['activity']  ['accumulated_time', 'amount']      15   0.8093  0.0087  0.7915  0.8228
# 8                     BPI12     gpt2         -1,-2  0.005          64              ['activity']            ['accumulated_time']      25   0.8074  0.0102  0.7850  0.8193
# 9                     BPI12     gpt2         -1,-2  0.005          64              ['activity']                              []       5   0.8058  0.0022  0.8035  0.8089
# 10                    BPI12     gpt2      -1,-2,-3  0.005          64  ['activity', 'resource']  ['accumulated_time', 'amount']       5   0.8388  0.0058  0.8313  0.8475
# 11                    BPI12     gpt2      -1,-2,-3  0.005          64  ['activity', 'resource']            ['accumulated_time']       5   0.8353  0.0053  0.8273  0.8397
# 12                    BPI12     gpt2      -1,-2,-3  0.005          64              ['activity']  ['accumulated_time', 'amount']       5   0.8145  0.0047  0.8094  0.8201
# 13                    BPI12     gpt2      -1,-2,-3  0.005          64              ['activity']            ['accumulated_time']       5   0.8122  0.0085  0.8038  0.8242
# 14                    BPI12     gpt2      -1,-2,-3  0.005          64              ['activity']                              []       5   0.8098  0.0072  0.8020  0.8178
# 15                    BPI12     gpt2   -1,-2,-3,-4  0.005          64  ['activity', 'resource']  ['accumulated_time', 'amount']       5   0.8372  0.0084  0.8232  0.8458
# 16                    BPI12     gpt2   -1,-2,-3,-4  0.005          64  ['activity', 'resource']            ['accumulated_time']       5   0.8205  0.0442  0.7418  0.8453
# 17                    BPI12     gpt2   -1,-2,-3,-4  0.005          64              ['activity']  ['accumulated_time', 'amount']       5   0.8140  0.0019  0.8118  0.8164
# 18                    BPI12     gpt2   -1,-2,-3,-4  0.005          64              ['activity']            ['accumulated_time']       5   0.7895  0.0426  0.7135  0.8138
# 19                    BPI12     gpt2   -1,-2,-3,-4  0.005          64              ['activity']                              []       5   0.8089  0.0193  0.7772  0.8237
# 20                    BPI12     gpt2          1,-1  0.005          64  ['activity', 'resource']  ['accumulated_time', 'amount']      10   0.8504  0.0034  0.8462  0.8571
# 21  BPI20PrepaidTravelCosts     gpt2            -1  0.005          64  ['activity', 'resource']  ['accumulated_time', 'amount']       5   0.8759  0.0034  0.8707  0.8791
# 22  BPI20PrepaidTravelCosts     gpt2            -1  0.005          64  ['activity', 'resource']            ['accumulated_time']       5   0.8639  0.0155  0.8468  0.8812
# 23  BPI20PrepaidTravelCosts     gpt2            -1  0.005          64              ['activity']  ['accumulated_time', 'amount']       5   0.8710  0.0110  0.8516  0.8788
# 24  BPI20PrepaidTravelCosts     gpt2            -1  0.005          64              ['activity']            ['accumulated_time']       5   0.8722  0.0078  0.8592  0.8782
# 25  BPI20PrepaidTravelCosts     gpt2            -1  0.005          64              ['activity']                              []       5   0.8568  0.0031  0.8531  0.8607
# 26  BPI20PrepaidTravelCosts     gpt2         -1,-2  0.005          64  ['activity', 'resource']  ['accumulated_time', 'amount']       5   0.8765  0.0021  0.8737  0.8791
# 27  BPI20PrepaidTravelCosts     gpt2         -1,-2  0.005          64  ['activity', 'resource']            ['accumulated_time']       5   0.8619  0.0232  0.8214  0.8791
# 28  BPI20PrepaidTravelCosts     gpt2         -1,-2  0.005          64              ['activity']  ['accumulated_time', 'amount']       5   0.8748  0.0021  0.8731  0.8782
# 29  BPI20PrepaidTravelCosts     gpt2         -1,-2  0.005          64              ['activity']            ['accumulated_time']       5   0.8768  0.0028  0.8743  0.8806
# 30  BPI20PrepaidTravelCosts     gpt2         -1,-2  0.005          64              ['activity']                              []       5   0.8569  0.0048  0.8513  0.8646
# 31  BPI20PrepaidTravelCosts     gpt2      -1,-2,-3  0.005          64  ['activity', 'resource']  ['accumulated_time', 'amount']       5   0.8727  0.0077  0.8601  0.8809
# 32  BPI20PrepaidTravelCosts     gpt2      -1,-2,-3  0.005          64  ['activity', 'resource']            ['accumulated_time']       5   0.8754  0.0064  0.8643  0.8797
# 33  BPI20PrepaidTravelCosts     gpt2      -1,-2,-3  0.005          64              ['activity']  ['accumulated_time', 'amount']       5   0.8740  0.0047  0.8679  0.8794
# 34  BPI20PrepaidTravelCosts     gpt2      -1,-2,-3  0.005          64              ['activity']            ['accumulated_time']       5   0.8598  0.0200  0.8371  0.8812
# 35  BPI20PrepaidTravelCosts     gpt2      -1,-2,-3  0.005          64              ['activity']                              []       5   0.8653  0.0107  0.8552  0.8779
# 36  BPI20PrepaidTravelCosts     gpt2   -1,-2,-3,-4  0.005          64  ['activity', 'resource']  ['accumulated_time', 'amount']       5   0.8774  0.0039  0.8734  0.8818
# 37  BPI20PrepaidTravelCosts     gpt2   -1,-2,-3,-4  0.005          64  ['activity', 'resource']            ['accumulated_time']       5   0.8626  0.0159  0.8362  0.8767
# 38  BPI20PrepaidTravelCosts     gpt2   -1,-2,-3,-4  0.005          64              ['activity']  ['accumulated_time', 'amount']       5   0.8760  0.0043  0.8701  0.8806
# 39  BPI20PrepaidTravelCosts     gpt2   -1,-2,-3,-4  0.005          64              ['activity']            ['accumulated_time']       5   0.8711  0.0037  0.8661  0.8740
# 40  BPI20PrepaidTravelCosts     gpt2   -1,-2,-3,-4  0.005          64              ['activity']                              []       5   0.8642  0.0064  0.8561  0.8704
# 41   BPI20RequestForPayment     gpt2            -1  0.005          64  ['activity', 'resource']  ['accumulated_time', 'amount']      10   0.8995  0.0013  0.8965  0.9007
# 42   BPI20RequestForPayment     gpt2            -1  0.005          64  ['activity', 'resource']            ['accumulated_time']      20   0.8973  0.0098  0.8560  0.9008
# 43   BPI20RequestForPayment     gpt2            -1  0.005          64              ['activity']  ['accumulated_time', 'amount']      10   0.8944  0.0159  0.8492  0.9007
# 44   BPI20RequestForPayment     gpt2            -1  0.005          64              ['activity']            ['accumulated_time']      20   0.8985  0.0032  0.8874  0.9015
# 45   BPI20RequestForPayment     gpt2            -1  0.005          64              ['activity']                              []      20   0.8975  0.0113  0.8500  0.9015
# 46   BPI20RequestForPayment     gpt2         -1,-2  0.005          64  ['activity', 'resource']  ['accumulated_time', 'amount']      10   0.8992  0.0024  0.8926  0.9010
# 47   BPI20RequestForPayment     gpt2         -1,-2  0.005          64  ['activity', 'resource']            ['accumulated_time']      10   0.8980  0.0048  0.8858  0.9015
# 48   BPI20RequestForPayment     gpt2         -1,-2  0.005          64              ['activity']  ['accumulated_time', 'amount']      10   0.8974  0.0045  0.8870  0.9008
# 49   BPI20RequestForPayment     gpt2         -1,-2  0.005          64              ['activity']            ['accumulated_time']      10   0.8994  0.0019  0.8940  0.9011
# 50   BPI20RequestForPayment     gpt2         -1,-2  0.005          64              ['activity']                              []      10   0.8995  0.0020  0.8939  0.9015
# 51   BPI20RequestForPayment     gpt2      -1,-2,-3  0.005          64  ['activity', 'resource']  ['accumulated_time', 'amount']      10   0.8990  0.0024  0.8934  0.9007
# 52   BPI20RequestForPayment     gpt2      -1,-2,-3  0.005          64  ['activity', 'resource']            ['accumulated_time']      10   0.8987  0.0028  0.8924  0.9013
# 53   BPI20RequestForPayment     gpt2      -1,-2,-3  0.005          64              ['activity']  ['accumulated_time', 'amount']      10   0.8980  0.0031  0.8928  0.9008
# 54   BPI20RequestForPayment     gpt2      -1,-2,-3  0.005          64              ['activity']            ['accumulated_time']      10   0.8992  0.0021  0.8937  0.9007
# 55   BPI20RequestForPayment     gpt2      -1,-2,-3  0.005          64              ['activity']                              []      10   0.8964  0.0078  0.8753  0.9011
# 56   BPI20RequestForPayment     gpt2   -1,-2,-3,-4  0.005          64  ['activity', 'resource']  ['accumulated_time', 'amount']      10   0.8976  0.0045  0.8861  0.9005
# 57   BPI20RequestForPayment     gpt2   -1,-2,-3,-4  0.005          64  ['activity', 'resource']            ['accumulated_time']      10   0.8994  0.0022  0.8932  0.9007
# 58   BPI20RequestForPayment     gpt2   -1,-2,-3,-4  0.005          64              ['activity']  ['accumulated_time', 'amount']      10   0.8950  0.0069  0.8821  0.9007
# 59   BPI20RequestForPayment     gpt2   -1,-2,-3,-4  0.005          64              ['activity']            ['accumulated_time']      10   0.8953  0.0079  0.8758  0.9003
# 60   BPI20RequestForPayment     gpt2   -1,-2,-3,-4  0.005          64              ['activity']                              []      10   0.8989  0.0038  0.8881  0.9010
# 61    BPI20TravelPermitData     gpt2            -1  0.005          64  ['activity', 'resource']            ['accumulated_time']       5   0.7478  0.0160  0.7282  0.7686
# 62    BPI20TravelPermitData     gpt2            -1  0.005          64              ['activity']            ['accumulated_time']       5   0.7396  0.0318  0.6839  0.7621
# 63    BPI20TravelPermitData     gpt2            -1  0.005          64              ['activity']                              []       5   0.7385  0.0169  0.7157  0.7543
#
#                                        project  total_params  trainable_params  embedding_size best_run_id
# 0        extra_feature_bpi12_unfreeze_last_001     124534299           7182363           768.0    p9ixmkgb
# 1        extra_feature_bpi12_unfreeze_last_001     124533531           7181595           768.0    olsrjn2u
# 2        extra_feature_bpi12_unfreeze_last_001     124486683           7134747           768.0    c8k6qu2a
# 3        extra_feature_bpi12_unfreeze_last_001     124485915           7133979           768.0    ww93fj5c
# 4        activity_only_unfreeze_last_bpi12_002     124484379           7132443           768.0    84j30zbq
# 5       extra_feature_bpi12_unfreeze_last2_001     124534299          14270235           768.0    r9p8v5nq
# 6       extra_feature_bpi12_unfreeze_last2_001     124533531          14269467           768.0    tcvhyed1
# 7       extra_feature_bpi12_unfreeze_last2_001     124486683          14222619           768.0    gmtt0zej
# 8       extra_feature_bpi12_unfreeze_last2_001     124485915          14221851           768.0    irtj3frs
# 9      extra_features_bpi12_unfreeze_last2_001     124484379          14220315           768.0    d043j448
# 10     extra_features_bpi12_unfreeze_last3_001     124534299          21358107           768.0    5i7dln0s
# 11     extra_features_bpi12_unfreeze_last3_001     124533531          21357339           768.0    5dxz13wq
# 12     extra_features_bpi12_unfreeze_last3_001     124486683          21310491           768.0    woskadxf
# 13     extra_features_bpi12_unfreeze_last3_001     124485915          21309723           768.0    3yqexr72
# 14     extra_features_bpi12_unfreeze_last3_001     124484379          21308187           768.0    9zdsh8ph
# 15     extra_features_bpi12_unfreeze_last4_001     124534299          28445979           768.0    q0wkpyq4
# 16     extra_features_bpi12_unfreeze_last4_001     124533531          28445211           768.0    5ntafkxk
# 17     extra_features_bpi12_unfreeze_last4_001     124486683          28398363           768.0    hnxk1l87
# 18     extra_features_bpi12_unfreeze_last4_001     124485915          28397595           768.0    2w9wjyil
# 19     extra_features_bpi12_unfreeze_last4_001     124484379          28396059           768.0    o9xfmyp9
# 20                      BPI12_spark_freeze_001     124552743          14288679           768.0    wnlzc31l
# 21      extra_features_unfreeze_last_bpi20_001     124498208           7146272           768.0    c5yyz3p2
# 22      extra_features_unfreeze_last_bpi20_001     124497440           7145504           768.0    2a16kbp1
# 23      extra_features_unfreeze_last_bpi20_001     124494368           7142432           768.0    hmiwwtac
# 24      extra_features_unfreeze_last_bpi20_001     124493600           7141664           768.0    45gdpznp
# 25      extra_features_unfreeze_last_bpi20_001     124492064           7140128           768.0    bxekz1up
# 26  extra_features_bpi20ptc_unfreeze_last2_001     124498208          14234144           768.0    blx2a0jq
# 27  extra_features_bpi20ptc_unfreeze_last2_001     124497440          14233376           768.0    qh8qup47
# 28  extra_features_bpi20ptc_unfreeze_last2_001     124494368          14230304           768.0    0n0zofav
# 29  extra_features_bpi20ptc_unfreeze_last2_001     124493600          14229536           768.0    v79xadd2
# 30  extra_features_bpi20ptc_unfreeze_last2_001     124492064          14228000           768.0    oqh1nkrd
# 31  extra_features_bpi20ptc_unfreeze_last3_001     124498208          21322016           768.0    t39v6ryb
# 32  extra_features_bpi20ptc_unfreeze_last3_001     124497440          21321248           768.0    ewu1ffy6
# 33  extra_features_bpi20ptc_unfreeze_last3_001     124494368          21318176           768.0    af4c46k7
# 34  extra_features_bpi20ptc_unfreeze_last3_001     124493600          21317408           768.0    irj6mg5n
# 35  extra_features_bpi20ptc_unfreeze_last3_001     124492064          21315872           768.0    7w21fnjr
# 36  extra_features_bpi20ptc_unfreeze_last4_001     124498208          28409888           768.0    6w668rkl
# 37  extra_features_bpi20ptc_unfreeze_last4_001     124497440          28409120           768.0    q57foraw
# 38  extra_features_bpi20ptc_unfreeze_last4_001     124494368          28406048           768.0    zsv110l7
# 39  extra_features_bpi20ptc_unfreeze_last4_001     124493600          28405280           768.0    thkle3yq
# 40  extra_features_bpi20ptc_unfreeze_last4_001     124492064          28403744           768.0    bebv6wve
# 41   extra_features_bpi20rfp_unfreeze_last_001     124478227           7126291           768.0    2n2w625t
# 42   extra_features_bpi20rfp_unfreeze_last_001     124477459           7125523           768.0    mwj6atg4
# 43   extra_features_bpi20rfp_unfreeze_last_001     124474387           7122451           768.0    h8ir6sn8
# 44   extra_features_bpi20rfp_unfreeze_last_001     124473619           7121683           768.0    zn3ygwsy
# 45   extra_features_bpi20rfp_unfreeze_last_001     124472083           7120147           768.0    6ev1v7dp
# 46  extra_features_bpi20rfp_unfreeze_last2_001     124478227          14214163           768.0    tbkk5jk4
# 47  extra_features_bpi20rfp_unfreeze_last2_001     124477459          14213395           768.0    8tyec48s
# 48  extra_features_bpi20rfp_unfreeze_last2_001     124474387          14210323           768.0    3ds7oqck
# 49  extra_features_bpi20rfp_unfreeze_last2_001     124473619          14209555           768.0    m5h3r3fx
# 50  extra_features_bpi20rfp_unfreeze_last2_001     124472083          14208019           768.0    ol1q8h1g
# 51  extra_features_bpi20rfp_unfreeze_last3_001     124478227          21302035           768.0    7m387sgs
# 52  extra_features_bpi20rfp_unfreeze_last3_001     124477459          21301267           768.0    crxviirm
# 53  extra_features_bpi20rfp_unfreeze_last3_001     124474387          21298195           768.0    93iyopkl
# 54  extra_features_bpi20rfp_unfreeze_last3_001     124473619          21297427           768.0    07v5j8ud
# 55  extra_features_bpi20rfp_unfreeze_last3_001     124472083          21295891           768.0    0atfbu87
# 56  extra_features_bpi20rfp_unfreeze_last4_001     124478227          28389907           768.0    4bb6qlvx
# 57  extra_features_bpi20rfp_unfreeze_last4_001     124477459          28389139           768.0    pg4361cd
# 58  extra_features_bpi20rfp_unfreeze_last4_001     124474387          28386067           768.0    fagz44aw
# 59  extra_features_bpi20rfp_unfreeze_last4_001     124473619          28385299           768.0    im9umf3a
# 60  extra_features_bpi20rfp_unfreeze_last4_001     124472083          28383763           768.0    cybvhvdq
# 61      extra_features_unfreeze_last_bpi20_001     124529717           7177781           768.0    gdfcbsb7
# 62      extra_features_unfreeze_last_bpi20_001     124525877           7173941           768.0    ihzulsee
# 63      extra_features_unfreeze_last_bpi20_001     124524341           7172405           768.0    bsjy851g
